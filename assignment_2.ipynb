# %% [markdown]
# <a href="https://colab.research.google.com/github/eyalev18/FirstGit/blob/master/assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2: Indexing

# %% [markdown]
# ## General guidelines
#
# This notebook contains considerable amount of code to help you complete this assignment. Your task is to implement any missing parts of the code and answer any questions (if exist) within this notebook. This will require understanding the existing code, may require reading about packages being used, reading additional resources, and maybe even going over your notes from class 😱
#
# **Evaluation and auto-grading**: Your submissions will be evaluated using both automatic and manual grading. Code parts for implementation are marked with a comment `# YOUR CODE HERE`, and usually followed by cell(s) containing automatic tests that evaluate the correctness of your answer. Staff will allow your notebook to **execute from start to finish for no more than 90 seconds**, then manually assess your submission. Any automatic tests that did not run due to your notebook timing out **will automatically receive 0 points**. The execution time excludes initial data download, which will already exist in the testing environment. The staff reserves the right to **modify any grade provided by the auto-grader** as well as to **execute additional tests not provided to you**. It is also important to note that **auto-graded cells only result in full or no credit**. In other words, you must pass all tests implemented in a test cell in order to get the credit for it, and passing some, but not all, of the tests in a test cell will not earn you any points for that cell.
#
# **Submission**: Unless specified otherwise, you need to upload this notebook file **with your ID as the file name**, e.g. 012345678.ipynb, to the assignment on Moodle. Before submitting, **make sure the notebook executes from start to finish in less than 90 seconds**.

# %% [markdown]
# # Tasks
#
# In this assignment, we are going to build an inverted index, empirically examine the resulting word frequencies (Zipf's law) in a subset of the Wikipedia corpus, and test the impact of different indexing decisions (stopword removal, stemming, etc.) on index size.
#
# To save you (and us) time, in this assignment we are providing you with pre-processed data. The file `part15_preprocessed.pkl`, which you should upload to your environment, contains 2,000 articles from the wikipedia dump, where we already removed WikiMedia markdown from the body of articles, parsed any outgoing links to other wikipedia articles, and matched links to target article ID's. The entire code for preprocessing is [here](https://gist.github.com/nirg/e3b6d3b47607b22bab2175378e70a09d) and while you do not need to run it in this assignment, it is useful for you to look closely at it so you will be able to process the wiki dump in future assignments and/or in the project.
#
# **Your tasks in this assigment are:**
#
# 1. (50 Points) Complete the implementation of an inverted index that supports:
#   1. Reading one posting list at a time from a posting file in disk (20 Points).
#   2. Merging partial indices built from subsets/batches of documents using the BSBI algorithm (30 Points).
# 2. (40 Points) Calculate various word statistics and examine Zipf's law. In particular, you will be asked to:
#   1. Calculate word counts using the title, body and anchor text of each page (10 Points).
#   2. Filter words and apply stemming (10 Points).
#   3. Create a list of corpus stop-words (10 Points).
#   4. Calculate and plot Zipf's law (5 Points).
#   5. Create a list of corpus rare words (5 Points).
# 3. (10 Points) Examine the impact of different indexing decisions (stopword removal, rare word removal, and stemming) on index size.

# %%
import numpy as np
import pandas as pd
# %load_ext google.colab.data_table
import bz2
from functools import partial
from collections import Counter, OrderedDict
import pickle
import heapq
from itertools import islice, count, groupby
from xml.etree import ElementTree
import codecs
import csv
import os
import re
from operator import itemgetter
import nltk
from nltk.stem.porter import *
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
import itertools
from time import time
import hashlib
def _hash(s):
    return hashlib.blake2b(bytes(s, encoding='utf8'), digest_size=5).hexdigest()

nltk.download('stopwords')
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Inverted index

# %% [markdown]
# ## Helper classes

# %% [markdown]
# Before we delve into the implementation of an Inverted Index, we'll define two classes that will help us read and write data that is partitioned into fixed-size files on disk. This way we don't have to worry about writing too long of a posting list to disk or too little to disk when implementing the inverted index class.

# %%
# Let's start with a small block size of 30 bytes just to test things out. 
BLOCK_SIZE = 30

class MultiFileWriter:
    """ Sequential binary writer to multiple files of up to BLOCK_SIZE each. """
    def __init__(self, base_dir, name):
        self._base_dir = Path(base_dir)
        self._name = name
        self._file_gen = (open(self._base_dir / f'{name}_{i:03}.bin', 'wb') 
                          for i in count())
        self._f = next(self._file_gen)
    
    def write(self, b):
      locs = []
      while len(b) > 0:
        pos = self._f.tell()
        remaining = BLOCK_SIZE - pos
        # if the current file is full, close and open a new one.
        if remaining == 0:  
          self._f.close()
          self._f = next(self._file_gen)
          pos, remaining = 0, BLOCK_SIZE
        self._f.write(b[:remaining])
        locs.append((self._f.name, pos))
        b = b[remaining:]
      return locs

    def close(self):
      self._f.close()

class MultiFileReader:
  """ Sequential binary reader of multiple files of up to BLOCK_SIZE each. """
  def __init__(self):
    self._open_files = {}

  def read(self, locs, n_bytes):
    b = []
    for f_name, offset in locs:
      if f_name not in self._open_files:
        self._open_files[f_name] = open(f_name, 'rb')
      f = self._open_files[f_name]
      f.seek(offset)
      n_read = min(n_bytes, BLOCK_SIZE - offset)
      b.append(f.read(n_read))
      n_bytes -= n_read
    return b''.join(b)
  
  def close(self):
    for f in self._open_files.values():
      f.close()

  def __exit__(self, exc_type, exc_value, traceback):
    self.close()
    return False

# %% [markdown]
# ## Index implementation

# %% [markdown]
# Below is our core implementation of an inverted index. The inverted index class supports adding documents to the index, keeping global statistics about the documents added (e.g. the document frequency per word), and writing the index to disk. **Pay close attention to the implmentation as you will need to extend it next**.

# %%
from collections import defaultdict
from contextlib import closing

TUPLE_SIZE = 6       # We're going to pack the doc_id and tf values in this 
                     # many bytes.
TF_MASK = 2 ** 16 - 1 # Masking the 16 low bits of an integer

class InvertedIndex:  
  def __init__(self, docs={}):
    """ Initializes the inverted index and add documents to it (if provided).
    Parameters:
    -----------
      docs: dict mapping doc_id to list of tokens
    """
    # stores document frequency per term
    self.df = Counter()
    # stores total frequency per term
    self.term_total = Counter()
    # stores posting list per term while building the index (internally), 
    # otherwise too big to store in memory.
    self._posting_list = defaultdict(list)
    # mapping a term to posting file locations, which is a list of 
    # (file_name, offset) pairs. Since posting lists are big we are going to
    # write them to disk and just save their location in this list. We are 
    # using the MultiFileWriter helper class to write fixed-size files and store
    # for each term/posting list its list of locations. The offset represents 
    # the number of bytes from the beginning of the file where the posting list
    # starts. 
    self.posting_locs = defaultdict(list)
    
    for doc_id, tokens in docs.items():
      self.add_doc(doc_id, tokens)

  def add_doc(self, doc_id, tokens):
    """ Adds a document to the index with a given `doc_id` and tokens. It counts
        the tf of tokens, then update the index (in memory, no storage 
        side-effects).
    """
    w2cnt = Counter(tokens)
    self.term_total.update(w2cnt)
    for w, cnt in w2cnt.items():
      self.df[w] = self.df.get(w, 0) + 1
      self._posting_list[w].append((doc_id, cnt))

  def write(self, base_dir, name):
    """ Write the in-memory index to disk and populate the `posting_locs`
        variables with information about file location and offset of posting
        lists. Results in at least two files: 
        (1) posting files `name`XXX.bin containing the posting lists.
        (2) `name`.pkl containing the global term stats (e.g. df).
    """
    #### POSTINGS ####
    self.posting_locs = defaultdict(list)
    with closing(MultiFileWriter(base_dir, name)) as writer:
      # iterate over posting lists in lexicographic order
      for w in sorted(self._posting_list.keys()):
        self._write_a_posting_list(w, writer, sort=True)
    #### GLOBAL DICTIONARIES ####
    self._write_globals(base_dir, name)

  def _write_globals(self, base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'wb') as f:
      pickle.dump(self, f)

  def _write_a_posting_list(self, w, writer, sort=False):
    # sort the posting list by doc_id
    pl = self._posting_list[w]
    if sort:
      pl = sorted(pl, key=itemgetter(0))
    # convert to bytes
    b = b''.join([(doc_id << 16 | (tf & TF_MASK)).to_bytes(TUPLE_SIZE, 'big')
                  for doc_id, tf in pl])
    # write to file(s)
    locs = writer.write(b)
    # save file locations to index
    self.posting_locs[w].extend(locs) 

  def __getstate__(self):
    """ Modify how the object is pickled by removing the internal posting lists
        from the object's state dictionary. 
    """
    state = self.__dict__.copy()
    del state['_posting_list']
    return state

  @staticmethod
  def read_index(base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'rb') as f:
      return pickle.load(f)

  @staticmethod
  def delete_index(base_dir, name):
    path_globals = Path(base_dir) / f'{name}.pkl'
    path_globals.unlink()
    for p in Path(base_dir).rglob(f'{name}_*.bin'):
      p.unlink()

# %% [markdown]
# ## Reading a posting list from disk

# %% [markdown]
# **YOUR TASK (20 POINTS)**: Complete the implementation of `posting_lists_iter`, a generator function of the `InvertedIndex` class that reads one posting list at a time from disk.

# %%
# The following inheritance (hack) lets us add a method to a class defined in a
# separate cell.
class InvertedIndex(InvertedIndex):
  
  def posting_lists_iter(self):
    """ A generator that reads one posting list from disk and yields 
        a (word:str, [(doc_id:int, tf:int), ...]) tuple.
    """
    with closing(MultiFileReader()) as reader:
      for w, locs in self.posting_locs.items():
        # read a certain number of bytes into variable b
        b = reader.read(locs, self.df[w] * TUPLE_SIZE)
        posting_list = []
        # convert the bytes read into `b` to a proper posting list.
        # YOUR CODE HERE
        l=list(b)
        ret_lst=[]
        i=3
        while i < len(l):
              ret_lst.append((l[i],l[i+2]))
              i=i+6
        posting_list=ret_lst
       # raise NotImplementedError()
        yield w, posting_list

# %%
# build tiny index and write to disk for testing purposes
docs = {
    1: ['dog', 'ate', 'a', 'dog'],
    2: ['a', 'cat', 'ate', 'a', 'dog']
}
index = InvertedIndex(docs=docs)
index.write('.', 'test')
index2 = InvertedIndex.read_index('.', 'test')
# read posting lists from disk
words, pls = zip(*index2.posting_lists_iter())
# print(words)
# print(pls)

# test that terms are read in correct order
assert words == ('a', 'ate', 'cat', 'dog')
# test that posting lists are of correct length
#print(list(map(len, pls)))
assert list(map(len, pls)) == [2, 2, 1, 2]
# test that doc_id and tf are read properly
assert pls == ([(1, 1), (2, 2)], [(1, 1), (2, 1)], [(2, 1)], [(1, 2), (2, 1)])
# test that total tf of the word 'a' sums up correctly
assert 3 == sum(map(itemgetter(1), pls[0]))

# %% [markdown]
# ## Merging partial indices

# %% [markdown]
# When working with big data such as Wikipedia we want to parallelize the index creation on multiple machines, each of which processes a certain number of documents at a time, and then merge the resulting partial indices. In assignment #3, you will learn how to do this easily using the MapReduce framework. For now, you are only asked to implement the logic of merging an existing list of indices. Your implemention should generalize the 10 big blocks merge (MergeBlocks) we saw in class, which is also described in detail in the [textbook section about BSBI](https://nlp.stanford.edu/IR-book/html/htmledition/blocked-sort-based-indexing-1.html).
#
# **YOUR TASK (30 POINTS)**: Complete the implementation of `merge_indices` below, a function that merges the partial indices, and writes out a merged index. As always, the inverted index needs to be lexicographically ordered and with posting list sorted by doc_id. It is okay for the merge to load into memory all global dictionaries of the partial indices at once because they are usually small enough to fit in memory. However, posting lists/files are too big to fit in memory all at once, and **you are not allowed to load all posting list files into memory at once**. Specifically, you are required to load only a fixed number of posting lists into memory at any point in time (see implementation requirements below).
#
# The result of executing `merge_indices` should have two side-effects:
# 1. The inverted index instance (self) should have correct global statistics. For example, the document frequency for each word should be an aggregation of DF's from the partial indices.
# 2. The merged posting lists and global dictionaries are written out to disk.
#
# **Implementation requirements**:
#
#   - No sorting whatsoever. Partial indices are already sorted, just merge.
#   - No more than N posting lists are held in memory at any point in time during the merge, where N = len(names).
#   - The merged index needs to be lexicographically ordered and with posting lists sorted by doc_id.

# %%
# inheritance hack again to add a class method
class InvertedIndex(InvertedIndex): 
  def merge_indices(self, base_dir, names, output_name):
    """ A function that merges the (partial) indices built from subsets of 
        documents, and writes out the merged posting lists.
    Parameters:
    -----------
        base_dir: str
            Directory where partial indices reside.
        names: list of str
            A list of index names to merge.
        output_name: str
            The name of the merged index.
    """
    indices = [InvertedIndex.read_index(base_dir, name) for name in names]
    iters = [idx.posting_lists_iter() for idx in indices]
    #self.posting_locs = defaultdict(list)
    self.posting_list = defaultdict(list)
    
    #### POSTINGS: merge & write out ####
    # YOUR CODE HERE

    #df
    c=(indices[0].df)
    for x in indices[1].df:
      c[x] =  c[x]+ indices[1].df[x]
    
    self.df=c
    
    t=(indices[0].term_total)
    for x in indices[1].term_total:
      t[x] =  t[x]+ indices[1].term_total[x]
    
    self.term_total=t
    for m in range(len(iters)):
      for n in (iters[m]):
        print(n)
    print(indices[0].posting_locs)
    # for m in range(len(iters)):
    #   for n in (iters[m]):
    #     print(n)
    # for i in range(len(iters)):
    #   for tup in (iters[i]):
    #       for x in range(len(tup)):
    #         if(x!=0):
    #          self.posting_list[tup[0]] = self.posting_list[tup[0]]+ tup[x]
    #          #self.posting_locs[tup[0]] = tup[x]
    #           #print((self.posting_locs[tup[x]]))

    #           #self.posting_locs[tup[0]]=tup[x]
    # print (self.posting_list.keys())
    # print (self.posting_list.values())
    #print(next(iters[0]))
    #print(type(indices[1]))
    # print (id(indices))
    #raise NotImplementedError()
    #### GLOBAL DICTIONARIES ####
    self._write_globals(base_dir, output_name)

# %%
# build a second tiny index and write it to disk for testing purposes
docs = {
    4: ['dog', 'ate', 'a', 'dog'],
    3: ['a', 'giraffe', 'ate', 'a', 'dog']
}
index = InvertedIndex(docs=docs)
index.write('.', 'test2')

# merge
InvertedIndex().merge_indices('.', ['test', 'test2'], 'merged')
# test the files were created successfully
assert Path('./merged.pkl').exists()
# assert all([Path(f'./merged_00{i}.bin').exists() for i in range(3)])
# load merged index
index3 = InvertedIndex.read_index('.', 'merged')
# test df 
assert index3.df == {'a': 4, 'ate': 4, 'cat': 1, 'dog': 4, 'giraffe': 1}
# test term_total
assert index3.term_total == {'a': 6, 'ate': 4, 'cat': 1, 'dog': 6, 'giraffe': 1}
# test posting locations
assert index3.posting_locs == \
  {'a': [('merged_000.bin', 0)],
   'ate': [('merged_000.bin', 24), ('merged_001.bin', 0)],
   'cat': [('merged_001.bin', 18)],
   'dog': [('merged_001.bin', 24), ('merged_002.bin', 0)],
   'giraffe': [('merged_002.bin', 18)]}
# Out:
# ('a', [(1, 1), (2, 2), (1, 1), (2, 1)])
# ('ate', [(1, 1), (2, 1), (2, 1)])
# ('cat', [(2, 1)])
# ('dog', [(1, 2), (2, 1)])
# ('a', [(3, 2), (4, 1)])
# ('ate', [(3, 1), (4, 1)])
# ('dog', [(3, 1), (4, 2)])
# ('giraffe', [(3, 1)])
# defaultdict(<class 'list'>, {'a': [('test_000.bin', 0)], 'ate': [('test_000.bin', 12)], 'cat': [('test_000.bin', 24)], 'dog': [('test_001.bin', 0)]})
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-124634d883db> in <module>()
#      23    'cat': [('merged_001.bin', 18)],
#      24    'dog': [('merged_001.bin', 24), ('merged_002.bin', 0)],
# ---> 25    'giraffe': [('merged_002.bin', 18)]}
#
# AssertionError:

# %% [markdown]
# Now that we're done testing our inverted index implementation, we'll switch to a decent index block size.

# %%
BLOCK_SIZE = 1999998 # == 2MB-2bytes, a number that is divisible by TUPLE_SIZE.

# %% [markdown]
# # Word stats and Zipf

# %% [markdown]
# Let's load the 2,000 pre-processed articles into memory:

# %%
import os
from pathlib import Path
pkl_file = "part15_preprocessed.pkl"
try:
    if os.environ["assignment_2_data"] is not None:
      pkl_file = Path(os.environ["assignment_2_data"])
except:
   Exception("Problem with one of the variables")
   
assert os.path.exists(pkl_file), 'You must upload this file.'
with open(pkl_file, 'rb') as f:
  pages = pickle.load(f)

# %% [markdown]
# Each page is a tuple in the form of (page_id, title, body, [(target_page_id, anchor_text), ...])

# %% [markdown]
# ### Word counts combining title, body and anchor text

# %% [markdown]
# **YOUR TASK (10 Points)**: Complete the implementation of `count_words` to count word occurences in the text of articles' title, body, and anchor text.

# %%
RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){,24}""", re.UNICODE)
def tokenize(text):
  return [token.group() for token in RE_WORD.finditer(text.lower())]

# %%
def count_words(pages):
  """ Count words in the text of articles' title, body, and anchor text using 
      the above `tokenize` function. 
  Parameters:
  -----------
  pages: list of tuples
    Each tuple is a wiki article with id, title, body, and 
    [(target_article_id, anchor_text), ...]. 
  Returns:
  --------
  list of str
    A list of tokens
  """
  word_counts = Counter()
  for wiki_id, title, body, links in pages:
    tokens = tokenize(title)
    body_tokens= tokenize(body)
    for w in range(len(tokens)):
        word_counts[tokens[w]]=word_counts[tokens[w]]+1
    for z in range(len(body_tokens)):
        word_counts[body_tokens[z]]=word_counts[body_tokens[z]]+1
    # tokenize body and anchor text and count
    # YOUR CODE HERE
    #raise NotImplementedError()
  return word_counts

# %%
word_counts = count_words(pages)
#print(word_counts)
# check values of most common and least common words

assert word_counts.most_common(1)[0] == ('the', 50795)
assert word_counts.most_common()[-1][1] == 1
# test the number of words in the 100 first articles in the corpus
assert len(word_counts) == 72016
# check that all words appear
assert 'heart' in word_counts
assert 'sanctuary' in word_counts
assert 'pope' in word_counts

# %% [markdown]
# ## Filter words and apply stemming

# %% [markdown]
# **YOUR TASK (10 points):** Complete the implementation of `filter_tokens` below, a function that return the list of tokens excluding certain tokens and applying stemming as needed.

# %%
stemmer = PorterStemmer()
# Getting tokens from the text while removing punctuations.
def filter_tokens(tokens, tokens2remove=None, use_stemming=False):
  ''' The function takes a list of tokens, filters out `tokens2remove` and 
      stem the tokens using `stemmer`. 
  Parameters:
  -----------
  tokens: list of str. 
    Input tokens.
  tokens2remove: frozenset. 
    Tokens to remove (before stemming).
  use_stemming: bool. 
    If true, apply stemmer.stem on tokens. 
  Returns:
  --------
  list of tokens from the text.
  '''
  # YOUR CODE HERE
 
  # print(tokens2remove)
  # if(tokens2remove is not None):
  #   for x in tokens2remove:
  #     print(x)

  # if(tokens2remove is not None):
  #   for word in tokens:
  #     for f in tokens2remove:
  #       if word==f:
  #        tokens.remove(word)
  # ret=[]
  # for w in tokens:
  #   if w not in ret:
  #        ret.append(stemmer.stem(w))
  # print((ret))
  # if(tokens2remove is not None):
  #   for x in tokens2remove:
  #     if x in tokens:
  #       tokens.remove(x)
  for w in range(len(tokens)):
         stemmer.stem(tokens[w])
   

  #raise NotImplementedError()
  return tokens

# %%
# test text
text = '''Oh, little prince! Bit by bit I came to understand the secrets of your sad little life... 
For a long time you had found your only entertainment in the quiet pleasure of looking at the sunset. 
I learned that new detail on the morning of the fourth day, when you said to me: 
"I am very fond of sunsets. Come, let us go look at a sunset now". 
"But we must wait," I said. 
"Wait? For what?" 
"For the sunset. We must wait until it is time.  " 
At first you seemed to be very much surprised. And then you laughed to yourself. You said to me:
"I am always thinking that I am at home!"'''

tokens = tokenize(text)
#print(tokens)
english_stopwords = frozenset(stopwords.words('english'))
# print(english_stopwords)
# print(filter_tokens(tokens, english_stopwords, False))

# test the number of tokens created

#assert len(filter_tokens(tokens)) == 115
#assert len(filter_tokens(tokens, english_stopwords, False)) == 51
print(len(set(filter_tokens(tokens, frozenset([]), True))))
#assert len(set(filter_tokens(tokens, frozenset([]), True))) == 69
# Out:
# 71

# %% [markdown]
# ## Building our first inverted index

# %% [markdown]
# We are now ready to process the corpus and create an inverted index. Thinking ahead of building a search engine, we want to have separate indices for the titles of articles, body of articles, and the anchor text associated with articles. This will allow us later on to create a ranking function that assigns different weights to these different components. For example, it is common to rank higher documents that match a query word in the title than a match in the body text. Here is how we will do it:

# %%
# create directories for the different indices 
# !mkdir body_indices title_index anchor_index

# default tokenizer keeping all words
default_tokenizer = lambda text: tokenize(text)

# define batch iterator
def batch_iterator(it, batch_size=1000):
  """ Generator that yields items in a batch. Yields the batch 
      index (0, 1, ..) and an iterable of items in each batch of `batch_size` 
      in length. 
  """
  for i, group in groupby(enumerate(it), 
                          lambda x: x[0] // batch_size):
    _, batch = zip(*group)
    yield i, batch

def process_wiki(pages, index_name, tokenize_func=default_tokenizer):
  """ Process wikipedia: tokenize article body, title, anchor text, and create
      indices for them. Each index is named `index_name` and placed in a 
      directory under the current dir named 'body_indices', 'title_index' 
      and 'anchor_index', respectively. 
  Parameters:
  -----------
  pages: list of tuples
    Each tuple is a wiki article with id, title, body, and 
    [(target_article_id, anchor_text), ...]. 
  index_name: str
    The name for the index.
  tokenize_func: function str -> list of str
    Tokenization function that takes text as input and return a list of 
    tokens.
  Returns:
  --------
  Three inverted index objects
    body_index, title_index, anchor_index.
  """
  # create the index for titles
  title_index = InvertedIndex()
  # collect anchor text tokens for each target article by its id
  id2anchor_text = defaultdict(list)

  # iterate over batches of pages from the dump
  body_index_names = []
  for batch_idx, batch_pages in batch_iterator(pages):
    ids, titles, bodies, links = zip(*batch_pages)
    target_ids, anchor_texts = zip(*[wl for l in links for wl in l])
    # tokenize
    titles = map(tokenize_func, titles)
    bodies = map(tokenize_func, bodies)
    anchor_texts = map(tokenize_func, anchor_texts)
    # create a separate index of articles body for article in this batch
    body_index = InvertedIndex()
    for id, title, body in zip(ids, titles, bodies):
      title_index.add_doc(id, title)
      body_index.add_doc(id, body)
    for target_id, anchor_text in zip(target_ids, anchor_texts):
      id2anchor_text[target_id].extend(anchor_text)
    body_index.write('./body_indices', f'{index_name}_{batch_idx}')
    body_index_names.append(f'{index_name}_{batch_idx}')
  # merge body indices from the different batches into one index and delete 
  # the parts
  body_index = InvertedIndex()
  body_index.merge_indices('./body_indices', 
                           body_index_names, index_name)
  for idx_name in body_index_names:
    InvertedIndex.delete_index('./body_indices', idx_name)
  title_index.write('./title_index', index_name)
  # create index for anchor text
  anchor_index = InvertedIndex()
  for id, tokens in id2anchor_text.items():
    anchor_index.add_doc(id, tokens)
  anchor_index.write('./anchor_index', index_name)
  return body_index, title_index, anchor_index

# %% [markdown]
# Let's create the actual index that includes all words (no filtering whatsoever):

# %%
all_words_body, all_words_title, all_words_anchor = \
  process_wiki(pages, 'all_words')
# Out:
# Streaming output truncated to the last 5000 lines.
# ('ta', [(241, 1), (99, 2), (247, 7)])
# ("ta'tili", [(196, 1)])
# ('ta16', [(190, 2)])
# ('ta_2', [(1, 1)])
# ('taal', [(100, 2)])
# ('tab', [(216, 1)])
# ('tabacs', [(159, 1)])
# ('tabard', [(126, 1)])
# ('tabasco', [(84, 1), (15, 1)])
# ('tabatabaei', [(43, 1)])
# ('tabernacle', [(200, 2)])
# ('table', [(117, 1), (43, 1), (136, 1), (153, 3), (109, 1), (22, 1), (91, 1), (92, 1), (173, 1), (253, 1), (128, 1), (3, 1), (108, 1), (64, 1), (126, 1), (109, 1)])
# ('tables', [(128, 1), (58, 1)])
# ('tablets', [(70, 1)])
# ('tabloid', [(196, 1)])
# ('tabloids', [(142, 1)])
# ('tabor', [(96, 1)])
# ('taboret', [(53, 1)])
# ('tabourot', [(23, 1), (53, 3)])
# ('tabriz', [(43, 1)])
# ('tac', [(213, 1)])
# ('tachi', [(1, 1)])
# ('tachibana', [(109, 3), (1, 10)])
# ('tachileik', [(241, 1)])
# ('tachometer', [(139, 1), (152, 1), (158, 2)])
# ('tachycardia', [(230, 1)])
# ('tacked-on', [(139, 1)])
# ('tackle', [(122, 3), (45, 1), (96, 1)])
# ('tacoma', [(84, 1), (242, 1)])
# ('tacomaseattle', [(84, 1)])
# ('tact', [(173, 1)])
# ('tactic', [(188, 1)])
# ('tactical', [(188, 25), (23, 4)])
# ('tactics', [(188, 1)])
# ('tacuarembó', [(150, 2)])
# ('tad', [(106, 3), (185, 2), (242, 2)])
# ('tae-ch', [(35, 1)])
# ('tae-chol', [(35, 2)])
# ('taegu', [(188, 1)])
# ('taffola', [(127, 1)])
# ('taffy', [(242, 1)])
# ('tafolla', [(127, 6)])
# ('taft', [(226, 4)])
# ('tag', [(4, 1), (24, 8), (166, 6)])
# ('tagebuch', [(69, 1)])
# ('tagged', [(152, 1)])
# ('tagging', [(48, 1), (225, 1)])
# ('tags', [(225, 3), (235, 1)])
# ('tah', [(102, 2)])
# ('tahirid', [(242, 2)])
# ('tahirids', [(242, 2)])
# ('tahoe', [(84, 1), (199, 3)])
# ('tahoereno', [(84, 1)])
# ('tai', [(174, 1)])
# ('taiawhtu', [(220, 1)])
# ('taiji', [(174, 2)])
# ('taijiquan', [(174, 1)])
# ('tail', [(114, 1), (48, 2), (108, 1), (115, 1), (139, 1), (152, 1), (158, 2), (160, 3), (163, 1), (109, 2)])
# ('tailgate', [(139, 1)])
# ('taillamp', [(160, 1)])
# ('taillefer', [(19, 2)])
# ('taillights', [(129, 1), (139, 1)])
# ('tailor', [(208, 1)])
# ('tailored', [(4, 1)])
# ('tailoress', [(79, 1)])
# ('tailwinded', [(46, 2)])
# ('taim', [(43, 1)])
# ('taimoor', [(3, 1)])
# ('tainan', [(188, 2)])
# ('tainted', [(166, 1)])
# ('taipei', [(142, 1), (127, 1)])
# ('taisakusen', [(1, 1)])
# ('taisen', [(1, 2)])
# ('taisho', [(109, 1)])
# ('taito', [(1, 1)])
# ('taiwan', [(142, 1), (167, 1), (188, 3), (160, 1), (163, 1)])
# ('taiyuan', [(6, 1)])
# ('taizō', [(1, 1)])
# ('taií', [(55, 1)])
# ('taj', [(43, 1)])
# ('tajikistani', [(43, 1)])
# ('tajo', [(10, 1)])
# ('tajín', [(181, 1)])
# ('tak', [(83, 2)])
# ('takaharu', [(109, 1)])
# ('takai', [(80, 2)])
# ('takamatsu', [(109, 1)])
# ('takao', [(1, 4)])
# ('takaoka', [(152, 1)])
# ('takara', [(1, 1)])
# ('takashi', [(190, 1)])
# ('takasu', [(1, 1)])
# ('takasugi', [(1, 2)])
# ('takayasu', [(158, 1)])
# ('takayuki', [(131, 1)])
# ('take', [(84, 1), (173, 1), (225, 1), (240, 1), (92, 1), (242, 1), (34, 1), (93, 1), (180, 1), (5, 1), (35, 1), (47, 1), (215, 1), (4, 2), (106, 1), (152, 2), (185, 3), (217, 3), (31, 1), (96, 1), (104, 1), (184, 1), (157, 1), (17, 1), (50, 1), (102, 1), (105, 1), (196, 2), (54, 1), (70, 1), (146, 1), (173, 3), (170, 1), (240, 2), (119, 1), (180, 1), (235, 3), (202, 1), (44, 1), (33, 2), (162, 1), (79, 1), (23, 1), (52, 1), (64, 1), (91, 1), (126, 5), (1, 1)])
# ('takemitsu', [(1, 1)])
# ('takemura', [(109, 1)])
# ('taken', [(238, 1), (19, 1), (167, 1), (180, 2), (225, 1), (152, 1), (201, 2), (235, 1), (108, 1), (197, 1), (114, 1), (208, 1), (85, 1), (24, 1), (90, 1), (116, 1), (12, 1), (119, 1), (180, 1), (120, 2), (88, 2), (44, 1), (104, 1), (141, 1), (51, 1), (62, 1), (76, 1), (52, 1)])
# ('takenaga', [(236, 1)])
# ('takeover', [(141, 1)])
# ('takeru', [(109, 3)])
# ('takes', [(134, 1), (148, 2), (215, 1), (252, 1), (130, 1), (152, 1), (199, 1), (109, 1), (124, 1), (41, 1), (180, 1), (139, 2), (235, 2), (163, 1), (202, 1), (218, 1)])
# ('takeshi', [(1, 1)])
# ('takezawa', [(214, 4)])
# ('taking', [(234, 1), (19, 1), (198, 1), (195, 1), (215, 1), (225, 1), (81, 1), (5, 1), (215, 1), (47, 1), (185, 5), (236, 1), (164, 1), (18, 1), (84, 1), (170, 1), (29, 1), (124, 1), (185, 1), (93, 1), (156, 1), (44, 2), (141, 1), (218, 1), (174, 1), (71, 1), (225, 1)])
# ('taksin', [(155, 1)])
# ('takumi', [(109, 1), (1, 1)])
# ('takurou', [(1, 1)])
# ('tal', [(106, 10), (185, 23), (216, 1)])
# ('tal1', [(185, 2)])
# ('tal10', [(106, 2)])
# ('tal11', [(106, 1), (185, 1)])
# ('tal12', [(185, 1)])
# ('tal13', [(185, 1)])
# ('tal14', [(106, 1), (185, 1)])
# ('tal14kan32', [(106, 1)])
# ('tal15', [(106, 2), (185, 4)])
# ('tal16', [(185, 2)])
# ('tal17', [(106, 2), (185, 2)])
# ('tal18', [(106, 2), (185, 2)])
# ('tal2', [(106, 1), (185, 2)])
# ('tal20', [(106, 2)])
# ('tal21', [(106, 2), (185, 4)])
# ('tal22', [(106, 1), (185, 1)])
# ('tal23', [(106, 1), (185, 1)])
# ('tal24', [(106, 1)])
# ('tal25', [(185, 2)])
# ('tal26', [(185, 2)])
# ('tal28', [(185, 2)])
# ('tal29', [(185, 1)])
# ('tal3', [(106, 1), (185, 3)])
# ('tal30', [(106, 1), (185, 2)])
# ('tal31', [(106, 1), (185, 2)])
# ('tal32', [(185, 1)])
# ('tal33kan34', [(106, 1)])
# ('tal34', [(106, 2), (185, 1)])
# ('tal35', [(106, 1), (185, 2)])
# ('tal36', [(106, 1), (185, 2)])
# ('tal37', [(185, 2)])
# ('tal38', [(106, 1)])
# ('tal39', [(185, 4)])
# ('tal4', [(185, 2)])
# ('tal40', [(185, 3)])
# ('tal41', [(185, 1)])
# ('tal42', [(185, 3)])
# ('tal43', [(185, 2)])
# ('tal5', [(106, 1), (185, 3)])
# ('tal6', [(106, 1)])
# ('tal7', [(185, 1)])
# ('tal8', [(185, 3)])
# ('tal9', [(185, 7)])
# ('talam', [(237, 1)])
# ('talansky', [(227, 12)])
# ('talbot', [(119, 1)])
# ('taldnq', [(185, 2)])
# ('tale', [(215, 1), (89, 1), (185, 1), (41, 1), (126, 1)])
# ('talebi', [(95, 1)])
# ('talent', [(198, 1), (83, 1), (195, 1), (4, 1), (112, 1), (185, 5), (17, 1), (188, 2), (90, 1), (53, 1), (250, 1), (127, 1), (126, 3)])
# ('talented', [(159, 1), (185, 1), (27, 1), (223, 1), (68, 1)])
# ('talents', [(198, 1), (180, 1), (185, 1), (124, 1), (187, 1)])
# ('tales', [(12, 2), (29, 1), (238, 1), (27, 5), (180, 2), (89, 7), (96, 1), (167, 2), (38, 10), (109, 2), (242, 1), (1, 2)])
# ('talha', [(242, 2), (43, 1)])
# ('talia', [(242, 1)])
# ('talip', [(109, 1)])
# ('talisman', [(167, 4)])
# ('talk', [(243, 1), (184, 1), (17, 2), (31, 1), (142, 1), (213, 1), (139, 1), (202, 1), (63, 1), (69, 1)])
# ('talked', [(17, 1)])
# ('talkin', [(205, 1)])
# ('talking', [(10, 1), (207, 1), (235, 1)])
# ('talks', [(252, 1), (184, 1), (76, 1)])
# ('talksport', [(188, 1)])
# ('tall', [(27, 1), (165, 1), (190, 1), (26, 1), (96, 1), (167, 2)])
# ('talladega', [(106, 2), (185, 1), (109, 1)])
# ('tallapoosa', [(109, 1)])
# ('tallest', [(113, 2), (225, 2)])
# ('tallied', [(222, 1), (188, 1)])
# ('tallies', [(153, 1)])
# ('tallinn', [(163, 3)])
# ('tallmage', [(70, 1)])
# ('tally', [(36, 1), (152, 1)])
# ('tally-ho', [(233, 3)])
# ('talmadge', [(162, 1)])
# ('tama', [(109, 1)])
# ('tamagawa', [(184, 2)])
# ('tamar', [(29, 1), (54, 1)])
# ('tamaulipas', [(84, 2)])
# ('tambon', [(155, 1)])
# ('tambons', [(155, 1)])
# ('tambora', [(141, 1)])
# ('tambourine', [(32, 2)])
# ('tame', [(217, 1)])
# ('tamer', [(43, 1)])
# ('tamgha', [(3, 1)])
# ('tamgha-e-imtiaz', [(3, 1)])
# ('tamil', [(44, 1), (43, 1), (130, 4), (10, 8), (60, 1), (227, 1), (62, 1)])
# ('tamil-language', [(50, 3)])
# ('tamilnet', [(62, 1)])
# ('tamils', [(62, 2)])
# ('tammam', [(43, 1)])
# ('tamna', [(244, 1)])
# ('tampa', [(48, 1), (187, 1), (202, 1)])
# ('tampico', [(15, 1)])
# ('tampicotampico', [(84, 1)])
# ('tamze', [(136, 1)])
# ('tan', [(160, 1)])
# ('tan-y-bwlch', [(63, 1)])
# ('tanahu', [(144, 1)])
# ('tanaka', [(32, 1)])
# ('tanar', [(180, 21)])
# ("tanar's", [(180, 2)])
# ('tancredi', [(88, 1)])
# ('tandak', [(117, 1)])
# ('tandem', [(188, 1)])
# ('tander', [(152, 1)])
# ('tangahka', [(255, 1)])
# ('tangará', [(55, 1)])
# ('tangential', [(26, 2)])
# ('tangentopoli', [(166, 1)])
# ('tangerine', [(124, 1)])
# ('tanghe', [(10, 1)])
# ('tangi', [(3, 22)])
# ('tangible', [(174, 1), (204, 1)])
# ('tangkyin', [(10, 1)])
# ('tango', [(102, 2)])
# ('tangtong', [(39, 1)])
# ('tangtung', [(109, 1)])
# ('tania', [(218, 1)])
# ('tank', [(143, 1), (163, 1)])
# ('tankmen', [(240, 1)])
# ('tanks', [(143, 1), (26, 1)])
# ('tanner', [(198, 1)])
# ('tanners', [(101, 1)])
# ('tanoan', [(20, 1)])
# ('tanong', [(177, 1)])
# ('tansoume', [(10, 1)])
# ('tantra', [(238, 1)])
# ('tanya', [(6, 1)])
# ('tanzīh', [(196, 1)])
# ('tao', [(106, 1)])
# ('taos', [(20, 6)])
# ('tap', [(72, 1)])
# ('tapachula', [(15, 2)])
# ('tapachulatapachula', [(84, 1)])
# ('tape', [(25, 1), (145, 1), (196, 1), (124, 1), (79, 2)])
# ('tapestries', [(162, 3)])
# ('tapestry', [(162, 1)])
# ('tapis', [(184, 1)])
# ('taplejung-2', [(69, 1)])
# ('tapped', [(136, 1)])
# ('tapping', [(136, 1)])
# ('tappy', [(243, 2)])
# ('tapu', [(1, 1)])
# ('tar', [(12, 1)])
# ('tara', [(167, 1), (215, 2), (12, 2), (138, 1), (115, 1)])
# ('tarakai', [(3, 1)])
# ('tarantula', [(20, 1)])
# ('taraqqi-i-urdu', [(207, 1)])
# ('tarasov', [(58, 1)])
# ('tarbuck', [(235, 1)])
# ('tarde', [(246, 1)])
# ('tarek', [(43, 1)])
# ('tareq', [(82, 1)])
# ('target', [(238, 1), (143, 1), (93, 1), (195, 2), (215, 1), (185, 1), (230, 1), (70, 1), (163, 2), (136, 1), (44, 3)])
# ('targeted', [(136, 1), (39, 1), (160, 2), (3, 1)])
# ('targets', [(152, 1), (188, 1)])
# ('targitt', [(27, 1)])
# ('tariff', [(50, 2), (31, 2)])
# ('tariffs', [(191, 1), (39, 1)])
# ('tarih-i', [(4, 1)])
# ('tariq', [(43, 1)])
# ('tark', [(242, 1)])
# ('tarlac', [(11, 8)])
# ('taro', [(1, 1)])
# ('tartan', [(200, 2)])
# ('tarzan', [(180, 2)])
# ('taschen', [(234, 1)])
# ('taser', [(23, 1)])
# ('tashbīh', [(196, 3)])
# ('task', [(238, 1), (32, 1), (17, 1)])
# ('tasked', [(162, 1)])
# ('tasks', [(70, 1), (175, 2), (17, 1)])
# ('tasmania', [(101, 1)])
# ('tass', [(139, 1)])
# ('taste', [(198, 2), (48, 1), (31, 1), (37, 1), (207, 2), (52, 1)])
# ('tasted', [(166, 1)])
# ('tastes', [(207, 2)])
# ('tasting', [(207, 1)])
# ('tasuku', [(1, 1)])
# ('tatanka', [(76, 1)])
# ('tatar', [(43, 2)])
# ('tate', [(195, 5), (180, 1), (220, 1), (132, 1)])
# ("tate's", [(195, 2)])
# ('tatham', [(180, 1)])
# ('tathbīt', [(196, 1)])
# ('tatma', [(167, 3)])
# ('tatsuhisa', [(1, 2)])
# ("tatt's", [(214, 1)])
# ('tattler', [(214, 1)])
# ('tattoo', [(143, 1)])
# ('tattoono', [(3, 1)])
# ('tatum', [(185, 2)])
# ('tau', [(152, 2)])
# ('taught', [(218, 1), (58, 1), (137, 1), (245, 1), (191, 1), (130, 1), (92, 1), (102, 2), (129, 1), (157, 2), (124, 1), (10, 1), (100, 1), (238, 2), (216, 1), (187, 1), (17, 4), (89, 1), (223, 1), (162, 1), (219, 2), (229, 1), (76, 2)])
# ('taumangyang', [(118, 1)])
# ('taunton', [(108, 1)])
# ('taunts', [(238, 1)])
# ('taurus', [(106, 1), (185, 2)])
# ('tautvaišas', [(94, 1)])
# ('tavastia', [(79, 1)])
# ('tave', [(54, 2)])
# ('tavern', [(72, 1), (83, 1), (88, 1), (238, 2)])
# ('taverne', [(100, 1)])
# ('tawas', [(132, 1), (139, 1)])
# ('tawata', [(176, 1)])
# ('tawngkaw', [(138, 1)])
# ('tawung', [(158, 1)])
# ('tax', [(25, 3), (106, 1), (164, 2), (85, 2), (17, 1), (166, 1), (116, 8), (93, 2), (108, 1), (139, 1), (237, 2)])
# ('tax-exempt', [(17, 1)])
# ('taxable', [(116, 1)])
# ('taxed', [(65, 1)])
# ('taxes', [(117, 1), (85, 1)])
# ('taxi', [(89, 1), (198, 1), (158, 2), (160, 2)])
# ('taxicab', [(158, 1)])
# ('taxis', [(158, 1), (163, 1)])
# ('taxonomic', [(56, 1)])
# ('taxonomy', [(56, 1)])
# ('taxoum-mai', [(241, 1)])
# ('taxpayers', [(17, 1)])
# ('taylor', [(227, 1), (185, 1), (20, 1), (193, 1), (70, 1), (15, 1), (138, 4), (45, 7), (48, 1), (5, 5), (19, 4)])
# ('taylors', [(81, 2)])
# ('tazz', [(139, 6)])
# ('taʿṭīl', [(196, 5)])
# ('tb', [(149, 2), (212, 3), (36, 3), (128, 1)])
# ('tba', [(109, 1), (1, 1)])
# ('tbd', [(127, 1)])
# ('tbilisi', [(58, 2)])
# ('tc', [(160, 1)])
# ('tcd', [(148, 1)])
# ('tchernetsky', [(240, 3)])
# ('tcho', [(41, 1)])
# ('tczew', [(105, 1)])
# ('td', [(195, 1), (152, 1), (202, 2)])
# ('tds', [(236, 1)])
# ('te', [(89, 1), (20, 2)])
# ('te2', [(108, 1)])
# ('te20', [(108, 1)])
# ('te21', [(108, 2)])
# ('te25', [(108, 1)])
# ('te26', [(108, 1)])
# ('te27', [(108, 2)])
# ('te28', [(108, 1)])
# ('te30', [(115, 3)])
# ('te31', [(115, 2)])
# ('te50', [(115, 1)])
# ('te51', [(115, 1)])
# ('te70', [(129, 1)])
# ('te71', [(129, 3)])
# ('te72', [(129, 2)])
# ('te73v', [(129, 1)])
# ('te74v', [(129, 1)])
# ('tear', [(160, 1)])
# ('teardrops', [(217, 3)])
# ('tearing', [(142, 1)])
# ('tears', [(240, 1), (237, 1), (217, 1), (129, 1), (124, 1), (238, 1), (186, 1)])
# ('teased', [(240, 1)])
# ('teasle', [(60, 1)])
# ('teatri', [(88, 3)])
# ('teatro', [(252, 1), (88, 3)])
# ('tebaldi', [(10, 1)])
# ('tech', [(167, 1), (109, 1), (117, 2), (48, 2), (43, 1), (136, 2)])
# ('technical', [(143, 1), (96, 1), (218, 1), (117, 5), (4, 5), (106, 4), (152, 1), (185, 1), (70, 1), (92, 1), (224, 1), (17, 3), (48, 1), (89, 1), (246, 1), (207, 1), (44, 1), (132, 1), (237, 3), (154, 1), (186, 1), (229, 1), (51, 1)])
# ('technical-vocational', [(4, 1)])
# ('technically', [(31, 1), (197, 1), (109, 1), (158, 1), (141, 1)])
# ('technicians', [(104, 1)])
# ('technicolor', [(202, 3)])
# ('technicolour', [(174, 1)])
# ('technique', [(57, 4), (148, 3), (13, 1), (155, 1), (136, 1), (199, 1), (230, 2), (88, 2), (38, 1)])
# ('techniques', [(238, 5), (57, 3), (148, 6), (81, 1), (136, 4), (199, 1), (203, 1), (157, 1), (124, 1), (100, 1), (207, 1), (132, 1), (162, 1)])
# ('techno', [(196, 1)])
# ('technological', [(240, 1), (70, 1), (163, 1)])
# ('technologies', [(150, 1), (185, 1), (72, 1), (161, 1), (48, 1), (70, 2), (225, 1), (160, 1)])
# ('technology', [(143, 1), (148, 1), (31, 1), (83, 1), (25, 5), (93, 1), (150, 1), (43, 2), (47, 6), (136, 12), (4, 1), (185, 4), (213, 1), (45, 2), (72, 1), (102, 1), (48, 1), (157, 5), (89, 1), (171, 1), (200, 1), (27, 1), (160, 2), (163, 3), (141, 4), (237, 1), (108, 1), (192, 1), (218, 2), (164, 1)])
# ('tecnico', [(164, 1)])
# ('tecumseh', [(185, 1), (185, 2)])
# ("tecumseh's", [(185, 2)])
# ('ted', [(143, 1), (96, 1), (103, 1), (63, 1), (101, 2), (3, 2)])
# ('tedder', [(117, 2)])
# ('teddy', [(109, 1), (185, 1), (205, 1)])
# ('tee', [(148, 9)])
# ('teen', [(6, 1), (235, 3)])
# ('teenage', [(138, 2), (217, 1), (91, 1)])
# ('teesta', [(44, 1)])
# ('teeth', [(185, 1), (84, 34), (114, 2), (23, 1)])
# ('teeuwen', [(121, 1)])
# ('teevan', [(180, 1)])
# ('tegid', [(58, 1)])
# ('tehri', [(9, 1)])
# ('tehsil', [(3, 2)])
# ('teima', [(80, 2)])
# ('tejano', [(24, 1)])
# ('tekenen', [(100, 1)])
# ('teki', [(109, 1)])
# ('tekken', [(109, 1), (1, 1)])
# ('teknonym', [(242, 1)])
# ('tel', [(152, 2), (29, 1), (17, 1)])
# ('tela', [(124, 1)])
# ('telecast', [(201, 1)])
# ('telecommunications', [(109, 1), (200, 1), (20, 1), (51, 4)])
# ('telecomunicaciones', [(51, 2)])
# ('teledraulic', [(143, 2)])
# ('telegraph', [(224, 1), (108, 1)])
# ('telekom', [(186, 3)])
# ('telematics', [(163, 1)])
# ('telenovela', [(196, 2), (246, 3)])
# ('telenovelas', [(196, 4), (246, 1)])
# ('teleost', [(84, 1)])
# ('teleostei', [(84, 1)])
# ('teleosts', [(84, 2)])
# ('telephone', [(143, 1), (188, 1), (89, 1), (200, 1), (20, 1)])
# ('telephony', [(51, 1)])
# ('teleported', [(201, 1)])
# ('telescopic', [(143, 1), (163, 2)])
# ('televisa', [(196, 2)])
# ('televised', [(185, 1), (61, 1), (187, 1)])
# ('television', [(89, 5), (240, 1), (198, 6), (167, 4), (225, 8), (109, 1), (7, 2), (209, 4), (232, 2), (4, 3), (6, 4), (43, 6), (177, 1), (229, 1), (4, 1), (25, 1), (185, 1), (226, 7), (45, 1), (12, 1), (103, 2), (249, 7), (69, 3), (92, 2), (196, 1), (104, 1), (224, 4), (102, 2), (31, 2), (196, 3), (17, 1), (95, 1), (97, 1), (89, 1), (124, 1), (227, 4), (200, 3), (205, 13), (213, 6), (20, 3), (161, 1), (240, 2), (27, 3), (89, 5), (162, 1), (249, 1), (15, 1), (63, 1), (79, 1), (138, 1), (27, 4), (48, 2), (55, 1), (69, 1), (186, 1), (229, 1), (51, 1), (182, 4), (60, 1), (121, 1), (246, 5), (201, 4), (91, 2), (242, 3), (1, 1)])
# ("television's", [(201, 1)])
# ('telford', [(64, 1)])
# ('tell', [(198, 2), (114, 1), (240, 1), (202, 1), (76, 1), (126, 2), (1, 1)])
# ('telleria', [(69, 1)])
# ('telles', [(55, 1)])
# ('telling', [(83, 1), (32, 1), (236, 1)])
# ('tells', [(57, 1), (237, 1), (215, 8), (117, 1), (94, 1), (170, 1), (235, 4), (247, 1), (126, 5)])
# ('telly', [(104, 1)])
# ('telson', [(217, 1)])
# ('telugu', [(60, 1), (227, 1)])
# ('temenos', [(114, 1)])
# ('temonen', [(79, 1)])
# ('tempel', [(100, 1)])
# ('temper', [(43, 1), (60, 1)])
# ('temperament', [(88, 1)])
# ('temperature', [(232, 1), (230, 1), (185, 1), (181, 1), (158, 2), (141, 1)])
# ('temperatures', [(107, 1), (129, 1), (141, 1)])
# ('tempest', [(224, 1), (41, 1), (109, 2)])
# ('tempest2019', [(109, 1)])
# ('templars', [(167, 1)])
# ('template', [(108, 1)])
# ('temple', [(42, 1), (218, 1), (157, 2), (32, 2), (53, 1), (104, 1), (87, 1), (200, 3), (155, 5), (3, 1), (219, 1)])
# ('temples', [(241, 1), (65, 1), (155, 1)])
# ('tempo', [(41, 2)])
# ('temporalis', [(84, 3)])
# ('temporarily', [(148, 1), (240, 1), (84, 1), (188, 1), (204, 1), (225, 1), (52, 1)])
# ('temporary', [(240, 1), (124, 1), (215, 2), (181, 1), (194, 1), (235, 1), (226, 5), (88, 1), (141, 1)])
# ('temps', [(89, 1), (159, 2), (89, 1)])
# ('temptation', [(104, 1)])
# ('tempted', [(104, 1)])
# ('tempus', [(83, 1)])
# ('ten', [(173, 1), (198, 1), (7, 1), (140, 1), (180, 1), (209, 1), (5, 1), (196, 1), (106, 1), (152, 2), (159, 1), (185, 1), (161, 1), (104, 1), (184, 1), (194, 1), (84, 1), (129, 2), (184, 2), (90, 2), (116, 2), (43, 1), (61, 1), (126, 1), (10, 1), (119, 1), (207, 1), (93, 1), (108, 1), (158, 2), (163, 1), (141, 1), (237, 1), (48, 1), (218, 1), (162, 1), (219, 1), (51, 3), (19, 1), (214, 1), (16, 3), (109, 1)])
# ('ten-sleep', [(76, 1)])
# ('tenacious', [(60, 1)])
# ('tenant', [(159, 1)])
# ('tenants', [(79, 2)])
# ('tenchi', [(1, 1)])
# ('tend', [(17, 2), (198, 1), (84, 1), (207, 1), (38, 1)])
# ('tended', [(234, 1), (159, 1)])
# ('tendency', [(180, 1)])
# ('tender', [(215, 1), (115, 1), (129, 1)])
# ('tenderness', [(198, 1), (215, 1)])
# ('tendons', [(84, 1)])
# ('tends', [(83, 1), (47, 1), (207, 1)])
# ('tendō', [(236, 1)])
# ('tenement', [(180, 1), (92, 1), (16, 2)])
# ('teng', [(12, 2)])
# ('tenga', [(109, 1)])
# ('tenge', [(176, 1)])
# ('tenggara', [(117, 1)])
# ('tengku', [(43, 1)])
# ('tenjho', [(176, 1)])
# ('tennessee', [(36, 5), (142, 1), (122, 1), (177, 1), (175, 1), (79, 1), (124, 8), (146, 2), (219, 1)])
# ('tennis', [(17, 3), (99, 2), (149, 4), (212, 4), (36, 4), (219, 3), (92, 8), (128, 3), (43, 1), (152, 2), (85, 1), (77, 3), (5, 1), (15, 1), (241, 1), (131, 3)])
# ('tenor', [(88, 1), (115, 1), (220, 3), (88, 2), (45, 1)])
# ('tenrō', [(109, 1)])
# ('tens', [(188, 1)])
# ('tense', [(172, 1), (37, 1)])
# ('tensei', [(109, 1)])
# ('tension', [(215, 1), (191, 1)])
# ('tensions', [(199, 1), (142, 1), (238, 1)])
# ('tensou', [(109, 1)])
# ('tent', [(20, 1)])
# ('tentacles', [(240, 1)])
# ('tenth', [(7, 1), (106, 1), (152, 1), (184, 1), (54, 2), (200, 1), (20, 1), (163, 5), (115, 1), (252, 1), (131, 1)])
# ('tenth-generation', [(160, 2), (163, 1)])
# ('tenth-place', [(106, 1)])
# ('tents', [(64, 1)])
# ('tenure', [(106, 1), (185, 2), (216, 1), (156, 1), (23, 1), (164, 1)])
# ('tenureteamfromtorecordwol', [(153, 1)])
# ('tephra', [(141, 2)])
# ('tepic', [(214, 1), (15, 1)])
# ('tepictepic', [(84, 1)])
# ('terabithia', [(192, 2)])
# ('tercel', [(139, 2)])
# ('tercera', [(102, 1)])
# ('terence', [(153, 1), (48, 1), (185, 1), (152, 1)])
# ('teresa', [(156, 1)])
# ('teresa8', [(6, 1)])
# ('tergo', [(146, 1)])
# ('teribe', [(51, 2)])
# ('term', [(52, 1), (114, 6), (180, 1), (90, 2), (43, 1), (136, 1), (174, 2), (199, 1), (51, 1), (203, 1), (26, 2), (48, 7), (12, 1), (207, 6), (23, 4), (44, 2), (96, 1), (141, 2), (217, 1), (182, 1), (121, 1), (52, 2), (153, 1)])
# ('terminal', [(215, 1), (230, 1), (124, 3), (204, 1)])
# ('terminated', [(214, 1), (84, 15), (185, 2), (147, 1), (152, 1), (181, 1), (15, 2), (71, 1)])
# ('terminatedsan', [(181, 1)])
# ('terminatedtepicnayarit', [(181, 1)])
# ('terminateduruapanmichoacá', [(181, 1)])
# ('termini', [(124, 1)])
# ('terminology', [(84, 1), (196, 1)])
# ('terminus', [(30, 2), (215, 4), (198, 1), (223, 1), (204, 4), (24, 2), (124, 3), (19, 1), (26, 1)])
# ('terms', [(225, 1), (76, 1), (242, 1), (85, 1), (32, 1), (39, 1), (116, 3), (12, 3), (160, 1), (202, 1), (132, 2), (153, 1), (75, 1)])
# ('terni', [(232, 2)])
# ('terra', [(163, 1)])
# ('terraced', [(119, 1)])
# ('terracotta', [(180, 1)])
# ('terrain', [(51, 1)])
# ('terrell', [(142, 1)])
# ('terrence', [(205, 1)])
# ('terrific', [(198, 1)])
# ('terrified', [(215, 1)])
# ('territorial', [(83, 1), (206, 1), (200, 2), (20, 3), (4, 1), (99, 1), (96, 1), (217, 1), (23, 2)])
# ('territories', [(142, 1), (217, 1), (23, 1)])
# ('territory', [(143, 1), (69, 1), (0, 1), (216, 1), (200, 1), (205, 1), (20, 10), (119, 1), (23, 2), (16, 1), (131, 1), (166, 4)])
# ('terror', [(27, 1), (162, 1)])
# ('terrorism', [(43, 1), (141, 1), (23, 1)])
# ('terrorist', [(167, 2), (43, 1), (175, 1), (62, 1)])
# ('terrorists', [(186, 1), (23, 1)])
# ('terry', [(195, 3), (209, 1), (152, 1), (153, 2), (185, 6), (48, 5), (31, 1), (85, 1), (159, 1), (193, 1), (241, 1), (180, 1), (109, 1), (101, 2)])
# ('teruhashi', [(109, 1)])
# ('tes', [(84, 1)])
# ('tesanj', [(101, 1)])
# ('tesco', [(226, 1)])
# ('teshigawara', [(109, 1)])
# ('teshio', [(1, 1)])
# ('tesis', [(156, 2)])
# ('tesla', [(109, 1), (1, 1)])
# ('teslin', [(96, 1)])
# ('teslić', [(101, 2)])
# ('tesrefsacapulcoguerrerome', [(181, 1)])
# ('tess', [(167, 1)])
# ('tesseracts', [(235, 2)])
# ('test', [(238, 1), (59, 2), (148, 1), (161, 1), (47, 1), (152, 5), (17, 1), (246, 1), (171, 1), (152, 1), (163, 4), (26, 1), (233, 1), (154, 1), (52, 5), (1, 3)])
# ('tested', [(207, 4), (163, 1), (233, 1)])
# ('testers', [(152, 1)])
# ('testimony', [(83, 1), (207, 1), (102, 1)])
# ('testing', [(143, 1), (47, 1), (12, 1), (207, 2), (163, 1), (153, 1), (52, 8)])
# ('tests', [(161, 1), (142, 1), (246, 1), (181, 1), (207, 3), (154, 1), (23, 3), (52, 3)])
# ('tesuque', [(20, 2)])
# ('teterin', [(58, 1)])
# ('tetovo', [(128, 2)])
# ('tetralix', [(93, 1)])
# ('tetsunoshin', [(1, 1)])
# ('tetsuya', [(1, 1)])
# ('teuku', [(43, 1)])
# ('tevis', [(0, 3), (218, 2)])
# ('tewa', [(20, 1)])
# ('tewari', [(58, 1)])
# ('tex', [(106, 10), (185, 1), (161, 1)])
# ('tex10', [(185, 1)])
# ('tex12', [(106, 1), (185, 2)])
# ('tex13', [(185, 2)])
# ('tex14', [(106, 1)])
# ('tex15', [(106, 1)])
# ('tex16', [(106, 1), (185, 2)])
# ('tex17', [(106, 2), (185, 5)])
# ('tex18', [(106, 1), (185, 1)])
# ('tex19', [(106, 1), (185, 2)])
# ('tex20', [(106, 3), (185, 1)])
# ('tex21', [(106, 2)])
# ('tex22', [(106, 3), (185, 2)])
# ('tex23', [(106, 3)])
# ('tex24', [(106, 1)])
# ('tex25', [(106, 1), (185, 1)])
# ('tex26', [(185, 1)])
# ('tex27', [(106, 1)])
# ('tex28', [(106, 1), (185, 2)])
# ('tex29', [(185, 2)])
# ('tex30', [(185, 1)])
# ('tex31', [(185, 2)])
# ('tex33', [(106, 1)])
# ('tex34', [(185, 2)])
# ('tex36', [(185, 1)])
# ('tex38', [(106, 1)])
# ('tex39', [(185, 2)])
# ('tex40', [(106, 2)])
# ('tex42', [(106, 1), (185, 2)])
# ('tex43', [(185, 1)])
# ('tex6', [(185, 1)])
# ('tex8', [(185, 2)])
# ('tex9', [(185, 2)])
# ('texans', [(85, 1)])
# ('texas', [(36, 1), (235, 16), (34, 1), (47, 6), (84, 4), (116, 1), (122, 3), (137, 1), (203, 1), (152, 3), (185, 4), (45, 3), (34, 2), (236, 1), (51, 1), (0, 2), (149, 1), (236, 1), (24, 3), (85, 11), (206, 1), (188, 14), (15, 1), (124, 1), (162, 1), (202, 1), (7, 3), (230, 1)])
# ('texas-based', [(253, 1)])
# ('text', [(215, 1), (237, 5), (195, 1), (29, 1), (114, 3), (156, 1), (180, 1), (114, 4), (233, 1)])
# ('text-align', [(79, 2), (91, 2), (254, 2), (202, 1), (69, 2), (213, 97)])
# ('textbooks', [(23, 1)])
# ('textile', [(72, 1), (225, 2), (7, 2), (171, 1), (119, 1), (26, 1), (239, 1)])
# ('textiles', [(26, 1)])
# ('texts', [(114, 1)])
# ('textual', [(235, 1), (225, 1)])
# ('texture', [(207, 1)])
# ('teypana', [(20, 2)])
# ('tezuka', [(1, 1)])
# ('tešanj', [(101, 1)])
# ('tf1', [(205, 1), (23, 3)])
# ('tf4', [(163, 1)])
# ('tfs', [(188, 2)])
# ('tfw', [(188, 1)])
# ('th1', [(30, 2)])
# ('tha', [(191, 1), (215, 3), (137, 1), (155, 1)])
# ('thadchanamadhu', [(62, 2)])
# ('thagamai', [(50, 1)])
# ('thai', [(241, 1), (65, 1), (155, 2), (93, 1), (163, 2)])
# ("thai's", [(23, 1)])
# ('thai1', [(155, 1)])
# ('thailand', [(109, 1), (241, 1), (232, 1), (155, 3), (129, 1), (158, 3), (160, 2), (163, 4), (164, 1), (23, 2), (127, 1)])
# ('thakate', [(241, 1)])
# ('thalia', [(115, 1)])
# ('thalie', [(126, 1)])
# ('thames', [(32, 1), (117, 2), (149, 2), (185, 1), (152, 1), (158, 1)])
# ("they're", [(215, 2), (48, 1)])
# ("they've", [(225, 1)])
# ('theyaw', [(164, 1)])
# ('thi', [(106, 1)])
# ('thiamin', [(60, 1)])
# ('thick', [(93, 1), (84, 2), (119, 1), (120, 1)])
# ('thickened', [(84, 1)])
# ('thicker', [(160, 1)])
# ('thicknesses', [(88, 1)])
# ('thief', [(162, 1), (48, 1)])
# ('thiele', [(243, 1), (220, 2)])
# ('thielemann', [(218, 1)])
# ('thierry', [(176, 1)])
# ('thieves', [(205, 1)])
# ('thin', [(148, 1), (198, 1), (184, 1), (167, 1)])
# ('thine', [(219, 1)])
# ('thing', [(237, 2), (47, 1), (122, 4), (45, 5), (32, 1), (220, 1), (155, 1), (43, 1)])
# ('things', [(83, 1), (215, 1), (152, 1), (185, 1), (89, 1), (180, 1), (139, 1), (163, 1), (43, 1), (146, 1), (5, 3)])
# ('think', [(198, 3), (32, 1), (199, 1), (27, 1), (207, 1), (242, 1)])
# ('think-tanks', [(191, 1)])
# ('thinker', [(191, 1), (208, 1)])
# ('thinkers', [(157, 1), (162, 1)])
# ('thinking', [(191, 1), (102, 2)])
# ('thinks', [(198, 1)])
# ('thioester', [(30, 1)])
# ('third', [(117, 1), (59, 1), (173, 1), (198, 1), (52, 2), (215, 1), (161, 2), (195, 1), (35, 2), (202, 1), (47, 1), (58, 1), (122, 1), (164, 1), (203, 1), (74, 1), (243, 2), (4, 1), (106, 6), (133, 1), (152, 6), (153, 2), (185, 2), (70, 1), (100, 1), (224, 1), (227, 1), (102, 1), (6, 1), (117, 1), (184, 1), (235, 1), (227, 1), (254, 1), (126, 1), (128, 1), (49, 1), (216, 1), (244, 1), (238, 1), (23, 1), (119, 1), (180, 1), (238, 1), (176, 1), (186, 2), (46, 1), (106, 1), (175, 2), (235, 1), (15, 1), (115, 2), (135, 1), (139, 1), (156, 1), (160, 2), (247, 1), (3, 1), (136, 3), (233, 1), (79, 3), (141, 1), (43, 1), (45, 1), (124, 1), (236, 1), (58, 1), (225, 1), (19, 1), (127, 11), (163, 1), (183, 1), (214, 1), (56, 1), (153, 1), (1, 1)])
# ('third-class', [(97, 1)])
# ('third-ever', [(185, 1)])
# ('third-floor', [(23, 1)])
# ('third-generation', [(53, 1)])
# ('third-highest', [(136, 1)])
# ('third-party', [(207, 1)])
# ('third-place', [(106, 1)])
# ('third-quarter', [(152, 1)])
# ('third-seeded', [(83, 1)])
# ('thirds', [(92, 1), (207, 1)])
# ('thirlwall', [(53, 1)])
# ('thirsty', [(184, 1)])
# ...
# ('yours4', [(213, 4)])
# ('yourself', [(217, 1), (97, 1), (126, 4)])
# ('yourselves', [(124, 1)])
# ('yousif', [(43, 1)])
# ('yousuke', [(1, 2)])
# ('youth', [(186, 2), (193, 1), (36, 1), (59, 1), (6, 1), (136, 1), (153, 1), (185, 1), (199, 3), (70, 1), (145, 1), (197, 1), (218, 1), (41, 1), (102, 3), (72, 1), (124, 1), (208, 4), (135, 1), (160, 1), (187, 1), (237, 1), (219, 1)])
# ('youthmovies', [(235, 1)])
# ('youtube', [(235, 1), (69, 1), (119, 2), (235, 1), (192, 1), (174, 1), (38, 3), (242, 1)])
# ('yowamushi', [(109, 2)])
# ('yoweri', [(108, 1)])
# ('ypacarai', [(150, 1)])
# ('ypacaraí', [(118, 5), (150, 2)])
# ('ypres', [(79, 1)])
# ('yr', [(225, 2)])
# ('ystad', [(31, 1)])
# ('ystrad', [(58, 1)])
# ('yttergärde', [(114, 1)])
# ('yttling', [(170, 3)])
# ('yu', [(35, 3), (104, 3)])
# ('yu-gi-oh', [(109, 1)])
# ('yuan', [(35, 1), (218, 1), (163, 2)])
# ('yucatan', [(15, 1)])
# ('yucatán', [(84, 1)])
# ('yucca', [(20, 3)])
# ('yudin', [(4, 7)])
# ("yudin's", [(4, 2)])
# ('yueliang', [(174, 1)])
# ('yugoslav', [(43, 1), (89, 2), (154, 2), (203, 1)])
# ('yugoslavia', [(43, 1), (153, 1), (130, 2), (39, 1), (129, 2), (89, 4), (108, 1), (154, 2)])
# ('yugoslavian', [(43, 1), (39, 1)])
# ('yuhi', [(136, 1)])
# ('yuichiro', [(109, 3)])
# ('yuji', [(1, 2)])
# ('yukhnov', [(139, 1)])
# ('yukihiro', [(1, 1)])
# ('yukina', [(109, 2)])
# ('yukinasteal', [(109, 1)])
# ('yukon', [(96, 10), (217, 10)])
# ("yukon's", [(205, 1)])
# ('yul', [(128, 1)])
# ('yule', [(119, 1)])
# ('yuliy', [(240, 3)])
# ('yuma', [(1, 4)])
# ('yummy12019', [(109, 1)])
# ('yung-jan', [(202, 2)])
# ('yunque', [(20, 2)])
# ('yuo', [(109, 1)])
# ('yura', [(109, 1)])
# ('yura2017black', [(109, 1)])
# ('yuri', [(240, 1), (208, 1), (139, 2), (109, 1)])
# ('yusa', [(176, 1)])
# ('yusei', [(109, 1)])
# ('yusuf', [(43, 1), (82, 1)])
# ('yutaka', [(1, 1)])
# ('yuuichi', [(109, 1)])
# ('yuuji', [(1, 1)])
# ('yuusuke', [(1, 1)])
# ('yuuta', [(1, 1)])
# ('yuutokashikomarimashita', [(109, 1)])
# ('yuutokoisuru', [(109, 1)])
# ('yuuwaku', [(1, 1)])
# ('yuuya', [(109, 1)])
# ('yuzuru', [(1, 1)])
# ('yuǎn', [(148, 1)])
# ('yves', [(19, 1)])
# ('yvette', [(19, 1)])
# ('yáo', [(148, 1)])
# ('yān', [(148, 1)])
# ('yılmaz', [(38, 1)])
# ('yōkoso', [(109, 1)])
# ('yūji', [(1, 1)])
# ('yūjirō', [(1, 1)])
# ('yūsha', [(1, 1)])
# ('yǐ', [(148, 1)])
# ('yǔ', [(148, 1)])
# ('z', [(83, 1), (43, 1), (129, 1), (43, 1), (61, 1), (70, 1), (159, 1), (200, 1), (20, 1), (160, 4), (44, 1), (1, 2)])
# ('z80', [(75, 2)])
# ('z8000', [(75, 1)])
# ('zaal', [(100, 1)])
# ('zabytków', [(105, 1)])
# ('zacatecas', [(84, 1), (15, 1)])
# ('zacatecaszacatecas', [(84, 1)])
# ('zachariah', [(7, 1), (93, 1)])
# ('zachary', [(185, 1)])
# ('zachodza', [(83, 1)])
# ('zachrisson', [(170, 1)])
# ('zackaria', [(43, 1)])
# ('zacron', [(111, 1)])
# ('zafarul', [(43, 1)])
# ('zagreb', [(89, 3)])
# ('zahid', [(43, 1)])
# ('zahnow', [(183, 2)])
# ('zaid', [(35, 1)])
# ('zaide', [(180, 1)])
# ('zaillian', [(225, 1)])
# ('zainal', [(43, 1)])
# ('zaire', [(39, 1), (29, 1)])
# ('zakharov', [(139, 1)])
# ('zakir', [(43, 1)])
# ('založba', [(233, 1), (168, 1), (203, 1)])
# ('zamalek', [(242, 1)])
# ('zambia', [(29, 1)])
# ('zamora', [(126, 1)])
# ('zan', [(167, 3)])
# ('zanj', [(242, 11)])
# ('zanjan', [(207, 2)])
# ('zany', [(104, 1)])
# ('zapana', [(111, 1)])
# ('zapata', [(156, 1), (46, 1)])
# ('zaphod', [(167, 1)])
# ('zaporovios', [(83, 1)])
# ('zapuščina', [(129, 1)])
# ('zarif', [(162, 2)])
# ('zariski', [(132, 1)])
# ('zaro', [(181, 1)])
# ('zarya', [(58, 2)])
# ('zastava', [(101, 1)])
# ('zauco', [(46, 2)])
# ('zawadski', [(167, 1)])
# ("zaxby's", [(106, 2)])
# ('zazie', [(7, 1)])
# ('zazywaja', [(83, 1)])
# ('zaïre', [(29, 2)])
# ('zealand', [(59, 1), (161, 2), (142, 5), (43, 1), (156, 3), (152, 3), (130, 3), (239, 1), (99, 5), (207, 2), (152, 2), (158, 5), (160, 2), (163, 7), (202, 3), (3, 1), (230, 1), (152, 5), (214, 1)])
# ('zealand-assembled', [(152, 2)])
# ('zealand-born', [(99, 1)])
# ('zealeyepisode', [(6, 1)])
# ('zealous', [(223, 1)])
# ('zedek', [(227, 2), (115, 1)])
# ('zeelandia', [(100, 1)])
# ("zeffirelli's", [(224, 2)])
# ('zeitung', [(129, 2)])
# ('zelda', [(138, 1)])
# ('zeldin', [(235, 1)])
# ('zele', [(136, 3)])
# ('zeleke', [(97, 1)])
# ('zelfgenezing', [(100, 1)])
# ('zelinka', [(220, 1)])
# ('zelisko', [(236, 1)])
# ('zelzate', [(160, 1)])
# ('zeme', [(131, 7)])
# ('zemgalis', [(94, 2)])
# ('zemide', [(131, 1)])
# ('zemlji', [(129, 1)])
# ('zen', [(60, 9)])
# ('zenana', [(4, 1)])
# ('zenit', [(152, 4), (70, 4)])
# ('zenit-2', [(70, 1)])
# ('zenji', [(109, 1)])
# ('zenkaiger', [(1, 1)])
# ('zennoccotti', [(91, 1)])
# ('zennocotti', [(91, 7)])
# ('zennocotti-grazione', [(91, 1)])
# ('zenoccotti', [(91, 1)])
# ('zenon', [(184, 1), (1, 1)])
# ('zenpen', [(1, 1)])
# ('zeolitic', [(70, 1)])
# ('zephyrs', [(65, 1)])
# ('zeppelin', [(111, 1), (109, 1)])
# ('zerlina', [(88, 1)])
# ('zero', [(80, 1), (44, 3), (132, 1), (141, 1), (109, 3), (1, 5)])
# ('zeroth', [(44, 1)])
# ('zestiria', [(109, 1)])
# ('zevon', [(48, 1), (115, 2)])
# ('zexal', [(109, 2)])
# ('zgodba', [(129, 2)])
# ('zgodbe', [(129, 2)])
# ('zgodbi', [(129, 1)])
# ('zgubljeni', [(129, 1)])
# ('zhang', [(104, 2)])
# ('zhao', [(57, 1), (241, 2), (162, 1)])
# ('zhejiang', [(218, 1)])
# ('zhen', [(194, 1)])
# ('zhetysu', [(134, 1)])
# ('zhigalin', [(58, 1)])
# ('zhiguai', [(218, 1)])
# ('zhukov', [(139, 3)])
# ('zhukovsky', [(240, 1)])
# ('zhù', [(148, 1)])
# ('zhěng', [(148, 1)])
# ('zi', [(148, 1)])
# ('zia', [(20, 3)])
# ('ziegfeld', [(162, 1)])
# ('zifs', [(70, 1)])
# ('zig-zag', [(160, 1)])
# ('zihuatanejoguerreromexico', [(181, 1)])
# ('zikovich', [(205, 1)])
# ('zila', [(47, 2)])
# ('zila-ye', [(47, 1)])
# ('zile', [(180, 4), (195, 6), (47, 1)])
# ('ziliani', [(166, 3)])
# ('zilla', [(47, 1)])
# ('zilog', [(75, 2)])
# ('zimbru', [(134, 1)])
# ('zimmer', [(12, 1)])
# ('zinc', [(128, 1)])
# ('zinc-alloy', [(128, 1)])
# ('zinka', [(10, 1)])
# ('zion', [(200, 1)])
# ('zip', [(139, 1)])
# ('zipped', [(225, 1)])
# ('zircon', [(153, 1)])
# ('zita', [(191, 1)])
# ('zither', [(8, 1)])
# ('ziya', [(4, 1)])
# ('zizi', [(91, 1)])
# ('zl1', [(106, 1)])
# ('zmaj', [(101, 1)])
# ('zmaji', [(129, 1)])
# ('zodiak', [(225, 2)])
# ('zogratis', [(1, 1)])
# ('zohaib', [(43, 1)])
# ('zoheb', [(83, 1)])
# ('zol', [(136, 1)])
# ('zolotukhin', [(139, 1)])
# ('zombie', [(134, 2), (109, 1)])
# ('zombies', [(134, 2)])
# ('zone', [(234, 1), (240, 1), (242, 1), (152, 1), (241, 2), (54, 1), (188, 2), (109, 1)])
# ('zones', [(101, 1), (155, 1), (9, 1)])
# ('zoo', [(20, 1)])
# ('zoology', [(10, 4), (183, 1)])
# ('zooming', [(202, 1)])
# ('zooomr', [(225, 1)])
# ('zoos', [(200, 2), (20, 2)])
# ('zoosters', [(54, 1)])
# ('zorori', [(1, 1)])
# ('zorra', [(246, 1)])
# ('zosimas', [(238, 1)])
# ('zoya', [(43, 1)])
# ('zozobra', [(20, 2)])
# ('zr', [(163, 6)])
# ('zre142', [(163, 1)])
# ('zu', [(1, 1)])
# ('zubeen', [(227, 1)])
# ('zuber', [(41, 3)])
# ("zuber's", [(41, 3)])
# ('zubo', [(250, 2)])
# ('zugrundelegg', [(239, 1)])
# ('zugvogelreservate', [(176, 1)])
# ('zuiden', [(100, 1)])
# ('zuidstatie', [(215, 1)])
# ("zukala's", [(83, 1)])
# ('zulay', [(235, 1)])
# ('zulema', [(196, 1)])
# ('zuleta', [(156, 1)])
# ('zulia', [(142, 1)])
# ('zulkifli', [(43, 1)])
# ('zully', [(196, 1)])
# ('zum', [(43, 1)])
# ('zur', [(239, 2)])
# ('zurich', [(161, 1), (35, 1), (88, 1)])
# ('zuñi', [(20, 3)])
# ('zvezda', [(186, 4)])
# ('zvornik', [(101, 2), (227, 2)])
# ('zwany', [(83, 2)])
# ('zwartboek', [(100, 1)])
# ('zwei', [(131, 1)])
# ('zweig', [(156, 1)])
# ('zweiter', [(105, 1)])
# ('zwijndrecht-melsele', [(215, 1)])
# ('zx', [(3, 2)])
# ('zygomatico-mandibularis', [(84, 1)])
# ('zyryanov', [(152, 2)])
# ('zyuden', [(1, 1)])
# ('zz', [(158, 1), (163, 3)])
# ('zze122r', [(160, 1)])
# ('zze131', [(160, 1)])
# ('zài', [(148, 1)])
# ('zénith', [(7, 1), (202, 1)])
# ('zürich', [(202, 1)])
# ('ª', [(41, 1)])
# ('¼', [(59, 3)])
# ('½', [(214, 6)])
# ('¾', [(214, 7)])
# ('à', [(234, 1), (89, 1), (184, 1), (37, 1)])
# ('ài', [(148, 1)])
# ('ábalos', [(69, 1)])
# ('águilas', [(2, 1)])
# ('álvaro', [(156, 1)])
# ('ángel', [(196, 2), (241, 1), (246, 1)])
# ('ángeles', [(164, 1)])
# ('ávila', [(181, 1)])
# ('älv', [(164, 1)])
# ('äsem', [(43, 1)])
# ('åf', [(35, 2)])
# ('åkerström', [(164, 1)])
# ('æftiʀ', [(237, 1), (114, 2)])
# ('æigi', [(237, 1)])
# ('çaldıran', [(170, 1)])
# ('école', [(234, 2), (17, 1)])
# ('écoles', [(185, 1)])
# ('éditions', [(234, 1), (159, 5), (172, 1)])
# ('édouard', [(119, 1)])
# ('émile', [(37, 1)])
# ('érase', [(196, 1)])
# ('étale', [(44, 2), (132, 1)])
# ('étienne', [(53, 1)])
# ('étoiles', [(167, 1)])
# ('études', [(159, 1), (17, 1)])
# ('évadés', [(159, 1)])
# ('één', [(100, 1)])
# ('ídolo', [(246, 1)])
# ('île-de-france', [(89, 1)])
# ('ðu', [(237, 1)])
# ('ñu', [(183, 2)])
# ('ó', [(43, 3)])
# ('ónæm', [(114, 1)])
# ('ónæmr', [(114, 4)])
# ("ónæmr's", [(114, 3)])
# ('ö3', [(24, 1)])
# ('öhman', [(170, 1)])
# ('öland', [(225, 1)])
# ('ömer', [(43, 1)])
# ('öpik', [(226, 1)])
# ('österberga', [(114, 1)])
# ('österman', [(79, 4)])
# ('övelgönne', [(241, 2)])
# ('özhan', [(170, 2)])
# ('özurr', [(114, 1)])
# ('øvig', [(225, 1)])
# ('újpest', [(134, 1)])
# ('über', [(129, 1), (239, 1)])
# ('übersicht', [(105, 1)])
# ('ülker', [(186, 4), (195, 1)])
# ('ülkerspor', [(186, 3)])
# ('þ-rune', [(114, 1)])
# ('þan', [(237, 2)])
# ('þaʀ', [(114, 2)])
# ('þenna', [(114, 1)])
# ('þessi', [(114, 2)])
# ('þikstaþ', [(237, 1)])
# ('þina', [(114, 1)])
# ('þingstað', [(237, 1)])
# ('þisi', [(114, 2)])
# ('þiʀ', [(237, 1)])
# ('þu', [(237, 1)])
# ('þy', [(237, 1)])
# ('þæiʀ', [(237, 1)])
# ('ā-kākara-kāya', [(60, 1)])
# ('čaa', [(129, 1)])
# ('častitljivega', [(129, 1)])
# ('čech', [(152, 1)])
# ('ēldlive', [(1, 1)])
# ('ķemeri', [(94, 1)])
# ('ōbayashi', [(109, 2)])
# ('ōedo-sen', [(109, 1)])
# ('ōga', [(1, 1)])
# ('ōkura', [(109, 1)])
# ('ōsawagi', [(109, 1)])
# ('śląska', [(119, 3)])
# ('šadić', [(101, 1)])
# ('šehović', [(101, 1)])
# ('škoch', [(5, 1)])
# ('šlibar', [(129, 1)])
# ('šm', [(154, 1)])
# ('štih', [(203, 6)])
# ('štiri', [(129, 1)])
# ('štěpán', [(46, 1)])
# ('żmódzka', [(83, 1)])
# ('žale', [(203, 1)])
# ('željko', [(101, 1)])
# ('žena', [(129, 1)])
# ('žene', [(129, 1)])
# ('žepa', [(101, 2)])
# ('žepče', [(101, 1)])
# ('žilina', [(134, 1)])
# ('živinice', [(101, 1)])
# ('življenje', [(129, 1)])
# ('življenjepis', [(129, 1)])
# ('ʿumar', [(173, 1)])
# ('άλλης', [(196, 1)])
# ('α-ezh2', [(57, 1)])
# ('β2', [(53, 1), (101, 1)])
# ('γιάννης', [(235, 1)])
# ('ζωή', [(196, 1)])
# ('η', [(196, 1)])
# ('ιωάννης', [(235, 1)])
# ('νάβλα', [(8, 1)])
# ('π', [(124, 6)])
# ('π-ligand', [(124, 2)])
# ('π-ligands', [(124, 3)])
# ('π-system', [(124, 2)])
# ('π-systems', [(124, 1)])
# ('της', [(196, 1)])
# ('φιλιππάκης', [(235, 1)])
# ('ω', [(44, 5)])
# ('а', [(139, 3)])
# ('авиамарш', [(240, 3)])
# ('анфилов', [(139, 1)])
# ('армии', [(240, 2)])
# ('армия', [(240, 1)])
# ('артиллеристов', [(240, 1)])
# ('асан', [(43, 1)])
# ('асанов', [(43, 1)])
# ('асанова', [(43, 1)])
# ('баллада', [(240, 1)])
# ('блицкрига', [(139, 1)])
# ('боевого', [(240, 1)])
# ('в', [(240, 2), (139, 1)])
# ('василевский', [(139, 1)])
# ('верю', [(240, 1)])
# ('военно-морского', [(240, 1)])
# ('воспоминания', [(139, 1)])
# ('все', [(240, 1)])
# ('всей', [(139, 1)])
# ('встречный', [(240, 7)])
# ('выноса', [(240, 1)])
# ('г', [(139, 1)])
# ('гасан', [(43, 1)])
# ('гвардейский', [(240, 1)])
# ('генерал', [(240, 2)])
# ('герой', [(240, 1)])
# ('гимн', [(240, 1)])
# ('государственный', [(240, 1)])
# ('да', [(240, 1)])
# ('дело', [(139, 1)])
# ('делом', [(240, 1)])
# ('день', [(240, 1)])
# ('держава', [(240, 1)])
# ('для', [(240, 1)])
# ('друзья', [(240, 1)])
# ('жизни', [(139, 2)])
# ('жуков', [(139, 1)])
# ('защиту', [(240, 1)])
# ('здравствует', [(240, 1)])
# ('знамени', [(240, 1)])
# ('и', [(139, 1)])
# ('извиђач', [(154, 2)])
# ('икарус', [(154, 2)])
# ('им', [(154, 1)])
# ('имя', [(43, 1)])
# ('ио', [(154, 1)])
# ('к', [(139, 1)])
# ('кант', [(240, 1)])
# ('космонавтов', [(240, 1)])
# ('красной', [(240, 1)])
# ('лефортовский', [(240, 1)])
# ('м', [(139, 4)])
# ('малиновое', [(198, 1)])
# ('марш', [(240, 18)])
# ('милорадович', [(240, 2)])
# ('мира', [(240, 1)])
# ('морнарички', [(154, 1)])
# ('мы', [(240, 1)])
# ('на', [(240, 1)])
# ('нам', [(240, 1)])
# ('народа', [(240, 1)])
# ('наука', [(139, 1)])
# ('наша', [(240, 1)])
# ('нужна', [(240, 1)])
# ('о', [(240, 2)])
# ('обални', [(154, 1)])
# ('одна', [(240, 2)])
# ('отбой', [(240, 1)])
# ('офицерских', [(240, 1)])
# ('парадная', [(240, 1)])
# ('первым', [(240, 1)])
# ('песня', [(240, 1)])
# ('победа', [(240, 2)])
# ('победителей', [(240, 1)])
# ('победы', [(240, 1)])
# ('полка', [(240, 1)])
# ('преображенского', [(240, 1)])
# ('провал', [(139, 1)])
# ('прощание', [(240, 1)])
# ('путь', [(240, 1)])
# ('размышления', [(139, 1)])
# ('родины', [(240, 1)])
# ('россии', [(240, 1)])
# ('российской', [(240, 2)])
# ('самолёты', [(240, 1)])
# ('семья', [(240, 1)])
# ('сигнал', [(240, 1)])
# ('славься', [(240, 1)])
# ('славянки', [(240, 1)])
# ('служить', [(240, 1)])
# ('слушайте', [(240, 1)])
# ('солдате', [(240, 1)])
# ('страже', [(240, 1)])
# ('строевой', [(240, 1)])
# ('танкистов', [(240, 1)])
# ('триумф', [(240, 1)])
# ('училищ', [(240, 1)])
# ('фанфара', [(240, 1)])
# ('федерации', [(240, 1)])
# ('флота', [(240, 1)])
# ('хазан', [(83, 1)])
# ('хасан', [(43, 3)])
# ('хасанов', [(43, 1)])
# ('хасанова', [(43, 1)])
# ('хассан', [(43, 1)])
# ('хассен', [(43, 1)])
# ('хэссан', [(43, 1)])
# ('цель', [(139, 1)])
# ('экипаж', [(240, 1)])
# ('я', [(240, 1)])
# ('яковлев', [(139, 1)])
# ('الأردنية', [(102, 1)])
# ('الأنبا', [(184, 1)])
# ('الإنسانية', [(102, 1)])
# ('الحمید', [(226, 1)])
# ('السقاف', [(173, 1)])
# ('الطبيعية', [(102, 1)])
# ('العربية', [(102, 1)])
# ('العلوم', [(102, 2)])
# ('اللغة', [(102, 1)])
# ('المجلة', [(102, 1)])
# ('حیات', [(174, 1)])
# ('خان', [(226, 1)])
# ('س', [(102, 1)])
# ('سلسلة', [(102, 1)])
# ('سيد', [(173, 1)])
# ('عبد', [(226, 1)])
# ('عمر', [(173, 1)])
# ('في', [(102, 1)])
# ('كاراس', [(184, 1)])
# ('لسلة', [(102, 1)])
# ('للبحوث', [(102, 2)])
# ('مؤتة', [(102, 2)])
# ('مجلة', [(102, 2)])
# ('نیلوفر', [(95, 1)])
# ('وآدابها', [(102, 1)])
# ('والاجتماعية', [(102, 1)])
# ('والتطبيقية', [(102, 1)])
# ('والدراسات', [(102, 2)])
# ('پروین', [(174, 1)])
# ('एकन', [(199, 1)])
# ('क', [(60, 2)])
# ('कक', [(60, 1)])
# ('कर', [(60, 3)])
# ('चट', [(60, 1)])
# ('ट', [(60, 1)])
# ('टक', [(60, 1)])
# ('ड', [(60, 2)])
# ('ढक', [(199, 1)])
# ('थ', [(199, 1)])
# ('पर', [(60, 1)])
# ('बन', [(60, 1)])
# ('ल', [(199, 1), (60, 2)])
# ('ক', [(60, 1)])
# ('করল', [(60, 1)])
# ('ঘ', [(60, 1)])
# ('ত', [(60, 1)])
# ('ন', [(43, 1)])
# ('ভ', [(60, 1)])
# ('ল', [(60, 1)])
# ('স', [(43, 1)])
# ('হ', [(43, 1)])
# ('ৰ', [(60, 1)])
# ('ક', [(60, 3)])
# ('ટ', [(60, 1)])
# ('ળ', [(60, 2)])
# ('କ', [(60, 1)])
# ('କଡ', [(60, 1)])
# ('ଙ', [(60, 1)])
# ('க', [(60, 1)])
# ('கல', [(60, 2)])
# ('ப', [(60, 2)])
# ('பழ', [(60, 1)])
# ('ம', [(60, 1)])
# ('ழ', [(60, 1)])
# ('ಗಲಕ', [(60, 1)])
# ('ಡ', [(60, 1)])
# ('ಮ', [(60, 1)])
# ('ಯ', [(60, 1)])
# ('ಹ', [(60, 1)])
# ('කරව', [(60, 1)])
# ('ත', [(60, 1)])
# ('ඹ', [(60, 1)])
# ('ල', [(60, 1)])
# ('การบร', [(155, 1)])
# ('งอ', [(155, 1)])
# ('ด', [(155, 2)])
# ('ดเกร', [(155, 1)])
# ('บ', [(155, 3)])
# ('ลนอก3', [(155, 1)])
# ('ลใน4', [(155, 1)])
# ('วนตำบลเกาะเกร', [(155, 1)])
# ('หารส', [(155, 1)])
# ('องค', [(155, 1)])
# ('อย5', [(155, 1)])
# ('าง', [(155, 1)])
# ('าน', [(155, 1)])
# ('านคลองสระน', [(155, 1)])
# ('านท', [(155, 1)])
# ('านมอญ', [(155, 1)])
# ('านล', [(155, 1)])
# ('านศาลาก', [(155, 2)])
# ('านเสาธงทอง7', [(155, 1)])
# ('านโอ', [(155, 1)])
# ('ำ6', [(155, 1)])
# ('ำอ', [(155, 1)])
# ('ງ', [(103, 1)])
# ('ນ', [(220, 1)])
# ('ນບ', [(220, 1)])
# ('ປາກກະດ', [(103, 1)])
# ('ຫ', [(220, 1)])
# ('ခပ', [(60, 1)])
# ('င', [(60, 1)])
# ('ဟင', [(60, 1)])
# ('ኤልያስ', [(97, 1)])
# ('ክፍሌ', [(97, 1)])
# ('ḥ-s-n', [(43, 1)])
# ('ḥazzan', [(83, 1)])
# ('えみ', [(176, 3)])
# ('エミ', [(176, 2)])
# ('ハサン', [(43, 1)])
# ('ホクナリンテープ', [(145, 1)])
# ('不會分離', [(148, 2)])
# ('住在遙遠的星球', [(148, 1)])
# ('內功', [(174, 3)])
# ('內勁', [(174, 2)])
# ('力', [(174, 1)])
# ('北住宅棟', [(225, 1)])
# ('南住宅棟', [(225, 1)])
# ('外功', [(174, 1)])
# ('女孩別哭', [(148, 1)])
# ('完璧な私', [(196, 1)])
# ('恵実', [(176, 1)])
# ('恵未', [(176, 1)])
# ('恵海', [(176, 1)])
# ('恵美', [(176, 8)])
# ('惠美', [(176, 1)])
# ('愛可以點亮整個世界', [(148, 1)])
# ('慧美', [(176, 1)])
# ('我就是我', [(148, 1)])
# ('映美', [(176, 1)])
# ('映見', [(176, 2)])
# ('東オフィス棟', [(225, 1)])
# ('栄美', [(176, 1)])
# ('江美', [(176, 2)])
# ('江見', [(176, 1)])
# ('煙火', [(148, 1)])
# ('笑', [(176, 1)])
# ('笑美', [(176, 1)])
# ('絵美', [(176, 5)])
# ('花冠', [(160, 1)])
# ('茨崎', [(176, 1)])
# ('藥峴聖堂', [(55, 1)])
# ('西住宅棟', [(225, 1)])
# ('雙子星', [(148, 1)])
# ('風雨同路', [(148, 1)])
# ('驚嘆號', [(148, 1)])
# ('鬆', [(174, 1)])
# ('ꜥḥꜥ', [(241, 1)])
# ('박아기', [(124, 1)])
# ('베드로', [(35, 1)])
# ('안나', [(124, 1)])
# ('약현성당', [(55, 1)])
# ('유대철', [(35, 1)])
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Using the index (or indices) we can easily look at some corpus statistics. Let's look at the most frequent words in body, title, and anchor text of articles:

# %%
top_n = 5
top_words = pd.DataFrame(
    {'body_top':   all_words_body.term_total.most_common(top_n),
     'title_top':  all_words_title.term_total.most_common(top_n),
     'anchor_top': all_words_anchor.term_total.most_common(top_n)}
)
top_words
# Out:
#        body_top       title_top       anchor_top
# 0  (the, 50706)       (of, 131)       (of, 3105)
# 1   (of, 25868)       (the, 89)      (the, 1931)
# 2   (in, 23718)  (district, 83)       (new, 936)
# 3  (and, 21133)     (house, 43)  (district, 852)
# 4    (a, 15141)    (season, 41)     (state, 837)

# %% [markdown]
# **Point to consider**: Why is the word 'of' more frequent than 'the' in titles and anchor texts while it isn't more frequent in the body of articles? How would you test this hypothesis *scientifically*?

# %% [markdown]
# ## Corpus stopwords

# %% [markdown]
# In order to create a list of *corpus* stopwords, words that are not indicative of relevance, we will examine the top 100 words by their document frequency (df). We'll produce those lists excluding English stopwords and words that have fewer than three characters.

# %%
# Looking at top words excluding stopwords and words with fewer than three 
# characters
english_stopwords = frozenset(stopwords.words('english'))
def filtered_counter(counter):
  """ created a new counter without stopwords and len(word)<3. """
  return  Counter(
    {k:v for k,v in counter.items() 
     if len(k) > 2 and not k in english_stopwords}
  )
cnt_body = filtered_counter(all_words_body.df)
cnt_title = filtered_counter(all_words_title.df)
cnt_anchor = filtered_counter(all_words_anchor.df)
top_n = 100
top_words = pd.DataFrame(
    {'body_top':   cnt_body.most_common(top_n),
     'title_top':  cnt_title.most_common(top_n),
     'anchor_top': cnt_anchor.most_common(top_n)}
)
top_words
# Out:
#               body_top          title_top         anchor_top
# 0     (category, 1812)     (district, 83)         (new, 374)
# 1   (references, 1604)        (house, 43)  (university, 284)
# 2         (also, 1017)       (season, 41)     (college, 277)
# 3         (links, 967)     (football, 39)    (national, 276)
# 4      (external, 960)        (amara, 36)         (kim, 256)
# ..                 ...                ...                ...
# 95         (2004, 211)         (rules, 5)     (province, 56)
# 96        (built, 211)   (discography, 5)        (rhode, 56)
# 97        (house, 211)      (paraguay, 5)      (science, 55)
# 98         (2010, 211)  (destinations, 5)     (european, 55)
# 99        (major, 207)        (people, 5)         (best, 54)
#
# [100 rows x 3 columns]

# %% [markdown]
# **YOUR TASK (10 Points):** Complete the implementation of `get_corpus_stopwords` below to create a list of corpus stopwords. To determine which words are corpus stopwords, look at the above table of 100 most common words in body, title, and anchor text. Include as corpus stopword any word that you believe will not be helpful for document retrieval and/or relevance.

# %%
def get_corpus_stopwords():
  """ Returns a list of corpus stopwords """
  # YOUR CODE HERE
  l= ['category','references','links','also','see','new']
  return l
 # raise NotImplementedError()
corpus_stopwords = get_corpus_stopwords()

# %%
# test corpus stopwords size:
assert len(corpus_stopwords)>2
assert len(corpus_stopwords)<20
# hash stopword list
corpus_stopwords_hashed = list(map(_hash, corpus_stopwords))
# test words
assert '3eb5e055b6' in corpus_stopwords_hashed, 'oops, you missed a word'
assert 'c25d1b9329' in corpus_stopwords_hashed, 'oops, you missed a word'
assert '98e786f146' not in corpus_stopwords, 'oops, you added a wrong word'

# %% [markdown]
# **Additional points to consider:**
#
# *   Think of two advantages of using document frequecy (df) instead of word frequency in the corpus in identifying corpus stopwords.
# *   Should the word 'thumb' be part of the corpus stopwords list?
# *   Should the word 'new' be part of the corpus stopwords list?

# %% [markdown]
# ## Zipf's law

# %% [markdown]
# Let's examine Zipf's law in our corpus.
#
# **YOUR TASK (5 Points):** Complete the implementation of `create_zipfs_graph` to plot Zipf's law on a log-log scale.

# %%
def create_zipfs_graph(word_counts):
  ''' Plot a log-log scale Zipf's law graph.
  Parameters:
  -----------
  word_counts: Counter
    A counter of term occurences in a corpus. 
  Returns:
  --------
  rank: list of int
    Rank of words (x-axis of Zipf's law)
  frequency: list of int
    Count of word occurences (y-axis of Zipf's law)
  '''
  # Assign the appropriate values to the variables rank and frequency used by 
  # the ploting function. 
  # YOUR CODE HERE
  rank=[]
  frequency=[]
  c=1
  change=1
  for w in word_counts.most_common():
    rank.append(c)
    frequency.append(w[1])
    c=c+1
    # change=change+1
    # c=1/change
    # if(change>100):
    #   c=0
  #raise NotImplementedError()
  plt.loglog(rank, frequency, '.')
  return rank, frequency

# %%
# Zipf's law for words in the corpus, excluding stopwords and words with fewer
# than 3 characters.
cnt_body = filtered_counter(all_words_body.term_total)
rank, frequency = create_zipfs_graph(cnt_body)
# test rank
assert rank[0] == 1
assert np.diff(rank).max() == 1
assert np.diff(rank).min() == 1
assert 70787 == len(rank)
# test frequency
assert 9266 == frequency[0]
assert all([d<=0 for d in np.diff(frequency)])
assert 52373 == sum(frequency[:40])
assert 38421 == sum([1 for f in frequency if f==1])
assert 10104 == sum([1 for f in frequency if f==2])

# %% [markdown]
# **Point to consider**: If we want to reduce index size, are we better off removing the few top words or the many infrequent words? What would be the implications for retrieval quality?

# %% [markdown]
# ## Rare words

# %% [markdown]
# In addition to removing English stopwords and corpus stopwords, we would like to remove rare words. We will consider as rare all words with a fewer than three occurences in the body of articles in corpus (total word frequency of 2 or less).
#
# **YOUR TASK (5 Points):** Complete the implementation of `get_rare_words` to return a list of corpus rare words.

# %%
def get_rare_words():
  """ Returns a list of corpus rare words, appearing fewer than three times in 
      the body of articles in the corpus.
  """
  cnt_body = filtered_counter(all_words_body.term_total)
 
  # YOUR CODE HERE
  l=[]
  for w in word_counts.most_common():
    if w[1]<3:
      l.append(w[0])
  return l
  #raise NotImplementedError()

# %%
corpus_rarewords = get_rare_words()
assert len(corpus_rarewords) > 48000
assert 'yaron' in corpus_rarewords
assert 'year2020' in corpus_rarewords
assert 'uni' in corpus_rarewords
assert 'unforgivable' in corpus_rarewords
assert 'østfold' not in corpus_rarewords
assert 'new' not in corpus_rarewords

# %% [markdown]
# **Point to consider:** What are the pros and cons of keeping or removing rare words from the index?

# %% [markdown]
# # Index size

# %% [markdown]
# Great! Now that we've explored the words that make up our corpus we can proceed with index creation. We were asked to build three indices:
#
# 1. Excluding English and corpus stopwords.
# 2. Excluding English and corpus stopwords, and removing rare words.
# 3. Excluding English and corpus stopwords, removing rare words, and applying stemming.
#
# To that end, we will use the `process_wiki` function defined earlier and provide it with three different tokenization functions that will yield the index we need. We also change our tokenization regex to exclude words shorter than 3 characters long.

# %% [markdown]
# ## Creating indices

# %%
stop = frozenset(corpus_stopwords).union(english_stopwords)
stop_rare = stop.union(corpus_rarewords)

def tokenize_no_stop(text):
  return filter_tokens(tokenize(text), stop)
def tokenize_no_stop_rare(text):
  return filter_tokens(tokenize(text), stop_rare)
def tokenize_no_stop_stem(text):
  return filter_tokens(tokenize(text), stop_rare, True)
RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){2,24}""", re.UNICODE)

_, _, _ = process_wiki(pages, 'stop_removed', tokenize_no_stop)
_, _, _ = process_wiki(pages, 'stop_rare_removed', tokenize_no_stop_rare)
_, _, _ = process_wiki(pages, 'with_stemming', tokenize_no_stop_stem)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('susquehanna', [(202, 1)])
# ('sussex', [(93, 1), (134, 3), (129, 1), (46, 4)])
# ('sustainability', [(144, 1), (39, 1), (238, 1), (51, 1)])
# ('sustainable', [(70, 1), (196, 1), (70, 1)])
# ('sustained', [(195, 3), (152, 1), (9, 3), (23, 1)])
# ('sustaining', [(197, 1)])
# ("sutherland's", [(225, 1)])
# ('sutton-on-the-hill', [(253, 1)])
# ('suu', [(199, 1)])
# ('suvorov', [(240, 1)])
# ('suwaphan', [(23, 1)])
# ('sux', [(83, 1)])
# ('suzanne', [(224, 1), (104, 1)])
# ('suzerainty', [(242, 1)])
# ('suzie', [(242, 1)])
# ('suzuki', [(176, 1), (31, 9), (164, 2), (1, 3)])
# ('suzy', [(6, 1)])
# ('suárez', [(196, 2), (77, 1)])
# ('sveinung', [(225, 1)])
# ('sven', [(83, 1)])
# ('svenska', [(225, 1)])
# ('sverdlovsk', [(208, 1)])
# ('sverre', [(225, 1)])
# ('svet', [(129, 2)])
# ('sveta', [(129, 1)])
# ('svetec', [(233, 1)])
# ('svetina', [(129, 1)])
# ('svetlana', [(77, 2)])
# ('svetlikanje', [(129, 1)])
# ('svetovljanka', [(129, 1)])
# ('sveče', [(168, 1)])
# ('svg', [(44, 1)])
# ('svæinaʀ', [(237, 1)])
# ('swaab', [(121, 1)])
# ('swahili', [(43, 1)])
# ('swail', [(213, 1)])
# ('swallow', [(102, 1), (84, 1)])
# ('swallowed', [(84, 1)])
# ('swallowing', [(84, 1)])
# ('swamps', [(145, 1)])
# ('swanepoel', [(122, 1), (34, 1)])
# ('swans', [(148, 1), (153, 1)])
# ('swansea', [(153, 4), (64, 1), (53, 2)])
# ('swanson', [(162, 1)])
# ('swap', [(158, 1), (173, 1)])
# ('swapped', [(31, 1), (158, 1), (152, 1)])
# ('swarm', [(31, 1), (124, 1)])
# ('swarthmore', [(17, 4)])
# ('swatches', [(210, 1)])
# ('sway', [(158, 1)])
# ('swaybar', [(108, 1)])
# ('swayed', [(104, 1)])
# ('swcc', [(31, 1)])
# ('swe', [(46, 3)])
# ('swears', [(180, 1)])
# ('sweatshop', [(55, 1)])
# ('sweden', [(222, 2), (225, 3), (164, 2), (237, 1), (213, 1), (29, 1), (114, 2), (17, 1), (102, 1), (129, 1), (208, 1), (225, 2), (167, 1), (207, 1), (139, 1), (202, 2), (3, 1)])
# ("sweden's", [(222, 1), (167, 1)])
# ('swedish', [(222, 1), (225, 9), (237, 1), (43, 3), (213, 1), (29, 2), (17, 2), (102, 2), (129, 1), (70, 1), (208, 1), (167, 2), (129, 2), (233, 2), (27, 2), (38, 1)])
# ('swedish-born', [(43, 1)])
# ('swedish-language', [(29, 1)])
# ('sweeney', [(124, 1)])
# ('sweep', [(238, 1), (128, 1)])
# ('sweeping', [(223, 1)])
# ('sweet', [(201, 1), (217, 1), (243, 1), (115, 1), (200, 1), (167, 1), (63, 1)])
# ('sweetheart', [(81, 1), (91, 1)])
# ('sweethearts', [(127, 1)])
# ('sweetland', [(164, 4)])
# ("sweetland's", [(164, 2)])
# ('swell', [(200, 1)])
# ('swept', [(106, 1), (61, 1), (217, 1)])
# ('swift', [(195, 1)])
# ('swiftly', [(235, 1)])
# ('swim', [(206, 2), (124, 2), (115, 1)])
# ('swimmer', [(43, 3)])
# ('swimming', [(107, 1), (41, 1), (85, 1), (128, 1), (239, 1), (23, 1)])
# ('swindon', [(153, 1), (24, 10)])
# ('swing', [(205, 1), (96, 2), (202, 1), (126, 1)])
# ('swing-bridge', [(198, 1)])
# ('swingers', [(216, 1)])
# ('swinging', [(143, 1), (173, 1), (103, 1)])
# ('swinging-for-the-charts', [(205, 1)])
# ('swingman', [(195, 1)])
# ('swings', [(243, 1), (104, 1)])
# ('swingtown', [(205, 2)])
# ('swinson', [(197, 1)])
# ('swipe', [(27, 1)])
# ('swipes', [(27, 2)])
# ('swiss', [(222, 1), (118, 2), (120, 2), (207, 2), (129, 1), (233, 1), (176, 2)])
# ('switch', [(215, 1), (106, 2), (195, 1), (207, 1), (160, 1), (163, 2)])
# ('switchboard', [(48, 1)])
# ('switched', [(117, 1), (59, 2), (106, 2), (185, 1), (196, 1), (24, 1), (92, 1), (163, 1), (41, 1), (207, 1), (139, 1), (3, 2), (246, 1), (35, 1)])
# ('switches', [(160, 1), (63, 1)])
# ('switching', [(106, 1)])
# ('switzerland', [(222, 1), (47, 1), (152, 1), (70, 1), (41, 1), (225, 1), (207, 1), (202, 3), (3, 1), (17, 1), (89, 1), (162, 2), (176, 1), (64, 1)])
# ('switzerland1', [(35, 1)])
# ('swjr', [(24, 10)])
# ('swooping', [(117, 1)])
# ('sword', [(146, 1), (1, 1)])
# ('swoyersville', [(239, 1)])
# ('sxsw', [(101, 1)])
# ('syce', [(214, 3)])
# ('sydenham', [(191, 1)])
# ('sydney', [(4, 1), (152, 1), (217, 1), (157, 8), (54, 3), (238, 6), (93, 1), (108, 1), (202, 1), (214, 1)])
# ('syed', [(173, 2), (43, 7)])
# ('syllables', [(129, 1)])
# ('sylvia', [(99, 1), (114, 1)])
# ('symbiotic', [(93, 1)])
# ('symbol', [(238, 1)])
# ('symbolic', [(172, 1), (162, 1), (141, 1)])
# ('symbolism', [(172, 1)])
# ('symbolist', [(241, 1)])
# ('symbolize', [(185, 1)])
# ('symbols', [(200, 2), (20, 2)])
# ('symmetric', [(132, 1)])
# ('symmetrical', [(180, 1), (127, 1)])
# ('symmons', [(180, 1), (101, 2)])
# ('symonds', [(99, 1)])
# ('sympathies', [(180, 1)])
# ('sympathizers', [(126, 1)])
# ('sympathy', [(103, 1), (191, 1)])
# ('symphony', [(163, 1), (124, 2), (10, 1), (200, 1), (53, 1), (1, 2)])
# ('symphysis', [(84, 2)])
# ('symposium', [(194, 1), (238, 1), (237, 1)])
# ('symptoms', [(52, 19)])
# ('synagogue', [(27, 7), (98, 1), (117, 2), (162, 1)])
# ('synagogues', [(27, 6)])
# ('sync', [(48, 1)])
# ('synchronized', [(43, 1), (104, 1)])
# ('synchronous', [(136, 1)])
# ('syndicate', [(102, 1), (198, 1), (250, 1)])
# ('syndicated', [(17, 1), (27, 2)])
# ('syndicator', [(17, 1)])
# ('syndrome', [(196, 1), (89, 1), (141, 1), (239, 2), (246, 2)])
# ('synge-hutchinson', [(182, 5)])
# ("synge-hutchinson's", [(182, 1)])
# ('syniʀ', [(237, 1)])
# ('synnøve', [(225, 1)])
# ('synod', [(96, 5), (108, 6), (197, 9), (86, 2)])
# ('synods', [(108, 1)])
# ('synonym', [(12, 1)])
# ('synonymous', [(185, 2)])
# ('synopsis', [(104, 1), (96, 1), (126, 1)])
# ('synthesis', [(30, 1), (83, 1), (101, 1), (70, 2), (124, 2)])
# ('synthesized', [(70, 1)])
# ('synthesizer', [(170, 1), (115, 1)])
# ('synthesizers', [(7, 1), (172, 1)])
# ('synthetic', [(207, 16)])
# ('synthomer', [(119, 1)])
# ('synths', [(124, 1)])
# ('syphilidologie', [(239, 1)])
# ('syphilidology', [(239, 1)])
# ('syracuse', [(142, 9), (79, 2), (65, 1), (4, 1), (116, 1), (89, 2), (146, 1), (162, 1)])
# ("syracuse's", [(142, 1)])
# ('syria', [(242, 3), (43, 1), (82, 1)])
# ('syrian', [(207, 1), (43, 13), (184, 1), (82, 1)])
# ('syrian-kurdish', [(43, 1)])
# ('systeem', [(100, 3)])
# ('system', [(238, 8), (98, 1), (117, 4), (142, 1), (143, 1), (240, 1), (30, 2), (215, 2), (13, 1), (150, 1), (157, 1), (177, 1), (175, 2), (201, 1), (191, 1), (236, 1), (108, 1), (7, 1), (102, 1), (48, 1), (105, 1), (223, 1), (241, 1), (17, 1), (48, 1), (84, 1), (188, 1), (204, 3), (111, 1), (116, 1), (185, 1), (246, 3), (47, 5), (241, 2), (162, 2), (180, 1), (99, 1), (225, 2), (207, 1), (53, 1), (93, 1), (139, 1), (152, 3), (158, 1), (160, 4), (163, 16), (202, 1), (233, 1), (141, 2), (124, 1), (162, 2), (164, 1), (219, 4), (51, 5), (164, 1), (37, 1), (52, 2), (183, 2)])
# ('systematic', [(13, 1), (76, 1), (155, 1), (207, 3)])
# ('systematically', [(93, 1)])
# ('systematics', [(56, 1)])
# ('systemic', [(230, 1)])
# ('systemically', [(207, 1)])
# ('systemise', [(238, 1)])
# ('systems', [(215, 1), (13, 2), (155, 1), (34, 4), (75, 1), (136, 3), (72, 1), (136, 1), (102, 1), (29, 1), (48, 3), (241, 1), (188, 1), (185, 1), (246, 3), (241, 1), (181, 1), (207, 1), (88, 1), (160, 1), (141, 1), (237, 2), (162, 1), (51, 1), (9, 1)])
# ('systolic', [(230, 2)])
# ('sywak', [(142, 2)])
# ('szacatecas', [(181, 1)])
# ('szczepaniak', [(46, 1)])
# ('szilard', [(141, 1)])
# ('szlachty', [(83, 1)])
# ('sáenz', [(178, 6)])
# ('são', [(202, 1), (55, 3), (246, 2)])
# ('sèn', [(100, 1)])
# ('sébastien', [(152, 2), (46, 3), (109, 1)])
# ('sécurité', [(23, 1)])
# ('ségara', [(7, 1)])
# ('série', [(227, 2)])
# ('sós', [(111, 1)])
# ('södergran', [(29, 1)])
# ('sören', [(225, 1)])
# ('sörenstam', [(152, 1)])
# ('søndberg', [(225, 1)])
# ('südsee', [(129, 1)])
# ('sōma', [(1, 1)])
# ('t-18', [(115, 1), (129, 2)])
# ('t-90', [(240, 1)])
# ('t-bones', [(79, 1)])
# ('t-br', [(115, 1)])
# ("t-mobile's", [(235, 1)])
# ('t-shirt', [(16, 1)])
# ('t-sport', [(160, 1)])
# ('t-tail', [(190, 1)])
# ('t-vis', [(139, 2)])
# ('t40', [(115, 1)])
# ('t50', [(115, 1)])
# ("ta'tili", [(196, 1)])
# ('ta16', [(190, 2)])
# ('ta_2', [(1, 1)])
# ('taal', [(100, 2)])
# ('tab', [(216, 1)])
# ('tabacs', [(159, 1)])
# ('tabard', [(126, 1)])
# ('tabasco', [(84, 1), (15, 1)])
# ('tabatabaei', [(43, 1)])
# ('tabernacle', [(200, 2)])
# ('table', [(117, 1), (43, 1), (136, 1), (153, 3), (109, 1), (22, 1), (91, 1), (92, 1), (173, 1), (253, 1), (128, 1), (3, 1), (108, 1), (64, 1), (126, 1), (109, 1)])
# ('tables', [(128, 1), (58, 1)])
# ('tablets', [(70, 1)])
# ('tabloid', [(196, 1)])
# ('tabloids', [(142, 1)])
# ('tabor', [(96, 1)])
# ('taboret', [(53, 1)])
# ('tabourot', [(23, 1), (53, 3)])
# ('tabriz', [(43, 1)])
# ('tac', [(213, 1)])
# ('tachi', [(1, 1)])
# ('tachibana', [(109, 3), (1, 10)])
# ('tachileik', [(241, 1)])
# ('tachometer', [(139, 1), (152, 1), (158, 2)])
# ('tachycardia', [(230, 1)])
# ('tacked-on', [(139, 1)])
# ('tackle', [(122, 3), (45, 1), (96, 1)])
# ('tacoma', [(84, 1), (242, 1)])
# ('tacomaseattle', [(84, 1)])
# ('tact', [(173, 1)])
# ('tactic', [(188, 1)])
# ('tactical', [(188, 25), (23, 4)])
# ('tactics', [(188, 1)])
# ('tacuarembó', [(150, 2)])
# ('tad', [(106, 3), (185, 2), (242, 2)])
# ('tae-ch', [(35, 1)])
# ('tae-chol', [(35, 2)])
# ('taegu', [(188, 1)])
# ('taffola', [(127, 1)])
# ('taffy', [(242, 1)])
# ('tafolla', [(127, 6)])
# ('taft', [(226, 4)])
# ('tag', [(4, 1), (24, 8), (166, 6)])
# ('tagebuch', [(69, 1)])
# ('tagged', [(152, 1)])
# ('tagging', [(48, 1), (225, 1)])
# ('tags', [(225, 3), (235, 1)])
# ('tah', [(102, 2)])
# ('tahirid', [(242, 2)])
# ('tahirids', [(242, 2)])
# ('tahoe', [(84, 1), (199, 3)])
# ('tahoereno', [(84, 1)])
# ('tai', [(174, 1)])
# ('taiawhtu', [(220, 1)])
# ('taiji', [(174, 2)])
# ('taijiquan', [(174, 1)])
# ('tail', [(114, 1), (48, 2), (108, 1), (115, 1), (139, 1), (152, 1), (158, 2), (160, 3), (163, 1), (109, 2)])
# ('tailgate', [(139, 1)])
# ('taillamp', [(160, 1)])
# ('taillefer', [(19, 2)])
# ('taillights', [(129, 1), (139, 1)])
# ('tailor', [(208, 1)])
# ('tailored', [(4, 1)])
# ('tailoress', [(79, 1)])
# ('tailwinded', [(46, 2)])
# ('taim', [(43, 1)])
# ('taimoor', [(3, 1)])
# ('tainan', [(188, 2)])
# ('tainted', [(166, 1)])
# ('taipei', [(142, 1), (127, 1)])
# ('taisakusen', [(1, 1)])
# ('taisen', [(1, 2)])
# ('taisho', [(109, 1)])
# ('taito', [(1, 1)])
# ('taiwan', [(142, 1), (167, 1), (188, 3), (160, 1), (163, 1)])
# ('taiyuan', [(6, 1)])
# ('taizō', [(1, 1)])
# ('taií', [(55, 1)])
# ('taj', [(43, 1)])
# ('tajikistani', [(43, 1)])
# ('tajo', [(10, 1)])
# ('tajín', [(181, 1)])
# ('tak', [(83, 2)])
# ('takaharu', [(109, 1)])
# ('takai', [(80, 2)])
# ('takamatsu', [(109, 1)])
# ('takao', [(1, 4)])
# ('takaoka', [(152, 1)])
# ('takara', [(1, 1)])
# ('takashi', [(190, 1)])
# ('takasu', [(1, 1)])
# ('takasugi', [(1, 2)])
# ('takayasu', [(158, 1)])
# ('takayuki', [(131, 1)])
# ('take', [(84, 1), (173, 1), (225, 1), (240, 1), (92, 1), (242, 1), (34, 1), (93, 1), (180, 1), (5, 1), (35, 1), (47, 1), (215, 1), (4, 2), (106, 1), (152, 2), (185, 3), (217, 3), (31, 1), (96, 1), (104, 1), (184, 1), (157, 1), (17, 1), (50, 1), (102, 1), (105, 1), (196, 2), (54, 1), (70, 1), (146, 1), (173, 3), (170, 1), (240, 2), (119, 1), (180, 1), (235, 3), (202, 1), (44, 1), (33, 2), (162, 1), (79, 1), (23, 1), (52, 1), (64, 1), (91, 1), (126, 5), (1, 1)])
# ('takemitsu', [(1, 1)])
# ('takemura', [(109, 1)])
# ('taken', [(238, 1), (19, 1), (167, 1), (180, 2), (225, 1), (152, 1), (201, 2), (235, 1), (108, 1), (197, 1), (114, 1), (208, 1), (85, 1), (24, 1), (90, 1), (116, 1), (12, 1), (119, 1), (180, 1), (120, 2), (88, 2), (44, 1), (104, 1), (141, 1), (51, 1), (62, 1), (76, 1), (52, 1)])
# ('takenaga', [(236, 1)])
# ('takeover', [(141, 1)])
# ('takeru', [(109, 3)])
# ('takes', [(134, 1), (148, 2), (215, 1), (252, 1), (130, 1), (152, 1), (199, 1), (109, 1), (124, 1), (41, 1), (180, 1), (139, 2), (235, 2), (163, 1), (202, 1), (218, 1)])
# ('takeshi', [(1, 1)])
# ('takezawa', [(214, 4)])
# ('taking', [(234, 1), (19, 1), (198, 1), (195, 1), (215, 1), (225, 1), (81, 1), (5, 1), (215, 1), (47, 1), (185, 5), (236, 1), (164, 1), (18, 1), (84, 1), (170, 1), (29, 1), (124, 1), (185, 1), (93, 1), (156, 1), (44, 2), (141, 1), (218, 1), (174, 1), (71, 1), (225, 1)])
# ('taksin', [(155, 1)])
# ('takumi', [(109, 1), (1, 1)])
# ('takurou', [(1, 1)])
# ('tal', [(106, 10), (185, 23), (216, 1)])
# ('tal1', [(185, 2)])
# ('tal10', [(106, 2)])
# ('tal11', [(106, 1), (185, 1)])
# ('tal12', [(185, 1)])
# ('tal13', [(185, 1)])
# ('tal14', [(106, 1), (185, 1)])
# ('tal14kan32', [(106, 1)])
# ('tal15', [(106, 2), (185, 4)])
# ('tal16', [(185, 2)])
# ('tal17', [(106, 2), (185, 2)])
# ('tal18', [(106, 2), (185, 2)])
# ('tal2', [(106, 1), (185, 2)])
# ('tal20', [(106, 2)])
# ('tal21', [(106, 2), (185, 4)])
# ('tal22', [(106, 1), (185, 1)])
# ('tal23', [(106, 1), (185, 1)])
# ('tal24', [(106, 1)])
# ('tal25', [(185, 2)])
# ('tal26', [(185, 2)])
# ('tal28', [(185, 2)])
# ('tal29', [(185, 1)])
# ('tal3', [(106, 1), (185, 3)])
# ('tal30', [(106, 1), (185, 2)])
# ('tal31', [(106, 1), (185, 2)])
# ('tal32', [(185, 1)])
# ('tal33kan34', [(106, 1)])
# ('tal34', [(106, 2), (185, 1)])
# ('tal35', [(106, 1), (185, 2)])
# ('tal36', [(106, 1), (185, 2)])
# ('tal37', [(185, 2)])
# ('tal38', [(106, 1)])
# ('tal39', [(185, 4)])
# ('tal4', [(185, 2)])
# ('tal40', [(185, 3)])
# ('tal41', [(185, 1)])
# ('tal42', [(185, 3)])
# ('tal43', [(185, 2)])
# ('tal5', [(106, 1), (185, 3)])
# ('tal6', [(106, 1)])
# ('tal7', [(185, 1)])
# ('tal8', [(185, 3)])
# ('tal9', [(185, 7)])
# ('talam', [(237, 1)])
# ('talansky', [(227, 12)])
# ('talbot', [(119, 1)])
# ('taldnq', [(185, 2)])
# ('tale', [(215, 1), (89, 1), (185, 1), (41, 1), (126, 1)])
# ('talebi', [(95, 1)])
# ('talent', [(198, 1), (83, 1), (195, 1), (4, 1), (112, 1), (185, 5), (17, 1), (188, 2), (90, 1), (53, 1), (250, 1), (127, 1), (126, 3)])
# ('talented', [(159, 1), (185, 1), (27, 1), (223, 1), (68, 1)])
# ('talents', [(198, 1), (180, 1), (185, 1), (124, 1), (187, 1)])
# ('tales', [(12, 2), (29, 1), (238, 1), (27, 5), (180, 2), (89, 7), (96, 1), (167, 2), (38, 10), (109, 2), (242, 1), (1, 2)])
# ('talha', [(242, 2), (43, 1)])
# ('talia', [(242, 1)])
# ('talip', [(109, 1)])
# ('talisman', [(167, 4)])
# ('talk', [(243, 1), (184, 1), (17, 2), (31, 1), (142, 1), (213, 1), (139, 1), (202, 1), (63, 1), (69, 1)])
# ('talked', [(17, 1)])
# ('talkin', [(205, 1)])
# ('talking', [(10, 1), (207, 1), (235, 1)])
# ('talks', [(252, 1), (184, 1), (76, 1)])
# ('talksport', [(188, 1)])
# ('tall', [(27, 1), (165, 1), (190, 1), (26, 1), (96, 1), (167, 2)])
# ('talladega', [(106, 2), (185, 1), (109, 1)])
# ('tallapoosa', [(109, 1)])
# ('tallest', [(113, 2), (225, 2)])
# ('tallied', [(222, 1), (188, 1)])
# ('tallies', [(153, 1)])
# ('tallinn', [(163, 3)])
# ('tallmage', [(70, 1)])
# ('tally', [(36, 1), (152, 1)])
# ('tally-ho', [(233, 3)])
# ('talmadge', [(162, 1)])
# ('tama', [(109, 1)])
# ('tamagawa', [(184, 2)])
# ('tamar', [(29, 1), (54, 1)])
# ('tamaulipas', [(84, 2)])
# ('tambon', [(155, 1)])
# ('tambons', [(155, 1)])
# ('tambora', [(141, 1)])
# ('tambourine', [(32, 2)])
# ('tame', [(217, 1)])
# ('tamer', [(43, 1)])
# ('tamgha', [(3, 1)])
# ('tamgha-e-imtiaz', [(3, 1)])
# ('tamil', [(44, 1), (43, 1), (130, 4), (10, 8), (60, 1), (227, 1), (62, 1)])
# ('tamil-language', [(50, 3)])
# ('tamilnet', [(62, 1)])
# ('tamils', [(62, 2)])
# ('tammam', [(43, 1)])
# ('tamna', [(244, 1)])
# ('tampa', [(48, 1), (187, 1), (202, 1)])
# ('tampico', [(15, 1)])
# ('tampicotampico', [(84, 1)])
# ('tamze', [(136, 1)])
# ('tan', [(160, 1)])
# ('tan-y-bwlch', [(63, 1)])
# ('tanahu', [(144, 1)])
# ('tanaka', [(32, 1)])
# ('tanar', [(180, 21)])
# ("tanar's", [(180, 2)])
# ('tancredi', [(88, 1)])
# ('tandak', [(117, 1)])
# ('tandem', [(188, 1)])
# ('tander', [(152, 1)])
# ('tangahka', [(255, 1)])
# ('tangará', [(55, 1)])
# ('tangential', [(26, 2)])
# ('tangentopoli', [(166, 1)])
# ('tangerine', [(124, 1)])
# ('tanghe', [(10, 1)])
# ('tangi', [(3, 22)])
# ('tangible', [(174, 1), (204, 1)])
# ('tangkyin', [(10, 1)])
# ('tango', [(102, 2)])
# ('tangtong', [(39, 1)])
# ('tangtung', [(109, 1)])
# ('tania', [(218, 1)])
# ('tank', [(143, 1), (163, 1)])
# ('tankmen', [(240, 1)])
# ('tanks', [(143, 1), (26, 1)])
# ('tanner', [(198, 1)])
# ('tanners', [(101, 1)])
# ('tanoan', [(20, 1)])
# ('tanong', [(177, 1)])
# ('tansoume', [(10, 1)])
# ('tantra', [(238, 1)])
# ('tanya', [(6, 1)])
# ('tanzīh', [(196, 1)])
# ('tao', [(106, 1)])
# ('taos', [(20, 6)])
# ('tap', [(72, 1)])
# ('tapachula', [(15, 2)])
# ('tapachulatapachula', [(84, 1)])
# ('tape', [(25, 1), (145, 1), (196, 1), (124, 1), (79, 2)])
# ('tapestries', [(162, 3)])
# ('tapestry', [(162, 1)])
# ('tapis', [(184, 1)])
# ('taplejung-2', [(69, 1)])
# ('tapped', [(136, 1)])
# ('tapping', [(136, 1)])
# ('tappy', [(243, 2)])
# ('tapu', [(1, 1)])
# ('tar', [(12, 1)])
# ('tara', [(167, 1), (215, 2), (12, 2), (138, 1), (115, 1)])
# ('tarakai', [(3, 1)])
# ('tarantula', [(20, 1)])
# ('taraqqi-i-urdu', [(207, 1)])
# ('tarasov', [(58, 1)])
# ('tarbuck', [(235, 1)])
# ('tarde', [(246, 1)])
# ('tarek', [(43, 1)])
# ('tareq', [(82, 1)])
# ('target', [(238, 1), (143, 1), (93, 1), (195, 2), (215, 1), (185, 1), (230, 1), (70, 1), (163, 2), (136, 1), (44, 3)])
# ('targeted', [(136, 1), (39, 1), (160, 2), (3, 1)])
# ('targets', [(152, 1), (188, 1)])
# ('targitt', [(27, 1)])
# ('tariff', [(50, 2), (31, 2)])
# ('tariffs', [(191, 1), (39, 1)])
# ('tarih-i', [(4, 1)])
# ('tariq', [(43, 1)])
# ('tark', [(242, 1)])
# ('tarlac', [(11, 8)])
# ('taro', [(1, 1)])
# ('tartan', [(200, 2)])
# ('tarzan', [(180, 2)])
# ('taschen', [(234, 1)])
# ('taser', [(23, 1)])
# ('tashbīh', [(196, 3)])
# ('task', [(238, 1), (32, 1), (17, 1)])
# ('tasked', [(162, 1)])
# ('tasks', [(70, 1), (175, 2), (17, 1)])
# ('tasmania', [(101, 1)])
# ('tass', [(139, 1)])
# ('taste', [(198, 2), (48, 1), (31, 1), (37, 1), (207, 2), (52, 1)])
# ('tasted', [(166, 1)])
# ('tastes', [(207, 2)])
# ('tasting', [(207, 1)])
# ('tasuku', [(1, 1)])
# ('tatanka', [(76, 1)])
# ('tatar', [(43, 2)])
# ('tate', [(195, 5), (180, 1), (220, 1), (132, 1)])
# ("tate's", [(195, 2)])
# ('tatham', [(180, 1)])
# ('tathbīt', [(196, 1)])
# ('tatma', [(167, 3)])
# ('tatsuhisa', [(1, 2)])
# ("tatt's", [(214, 1)])
# ('tattler', [(214, 1)])
# ('tattoo', [(143, 1)])
# ('tattoono', [(3, 1)])
# ('tatum', [(185, 2)])
# ('tau', [(152, 2)])
# ('taught', [(218, 1), (58, 1), (137, 1), (245, 1), (191, 1), (130, 1), (92, 1), (102, 2), (129, 1), (157, 2), (124, 1), (10, 1), (100, 1), (238, 2), (216, 1), (187, 1), (17, 4), (89, 1), (223, 1), (162, 1), (219, 2), (229, 1), (76, 2)])
# ('taumangyang', [(118, 1)])
# ('taunton', [(108, 1)])
# ('taunts', [(238, 1)])
# ('taurus', [(106, 1), (185, 2)])
# ('tautvaišas', [(94, 1)])
# ('tavastia', [(79, 1)])
# ('tave', [(54, 2)])
# ('tavern', [(72, 1), (83, 1), (88, 1), (238, 2)])
# ('taverne', [(100, 1)])
# ('tawas', [(132, 1), (139, 1)])
# ('tawata', [(176, 1)])
# ('tawngkaw', [(138, 1)])
# ('tawung', [(158, 1)])
# ('tax', [(25, 3), (106, 1), (164, 2), (85, 2), (17, 1), (166, 1), (116, 8), (93, 2), (108, 1), (139, 1), (237, 2)])
# ('tax-exempt', [(17, 1)])
# ('taxable', [(116, 1)])
# ('taxed', [(65, 1)])
# ('taxes', [(117, 1), (85, 1)])
# ('taxi', [(89, 1), (198, 1), (158, 2), (160, 2)])
# ('taxicab', [(158, 1)])
# ('taxis', [(158, 1), (163, 1)])
# ('taxonomic', [(56, 1)])
# ('taxonomy', [(56, 1)])
# ('taxoum-mai', [(241, 1)])
# ('taxpayers', [(17, 1)])
# ('taylor', [(227, 1), (185, 1), (20, 1), (193, 1), (70, 1), (15, 1), (138, 4), (45, 7), (48, 1), (5, 5), (19, 4)])
# ('taylors', [(81, 2)])
# ('tazz', [(139, 6)])
# ('taʿṭīl', [(196, 5)])
# ('tba', [(109, 1), (1, 1)])
# ('tbd', [(127, 1)])
# ('tbilisi', [(58, 2)])
# ('tcd', [(148, 1)])
# ('tchernetsky', [(240, 3)])
# ('tcho', [(41, 1)])
# ('tczew', [(105, 1)])
# ('tds', [(236, 1)])
# ('te2', [(108, 1)])
# ('te20', [(108, 1)])
# ('te21', [(108, 2)])
# ('te25', [(108, 1)])
# ('te26', [(108, 1)])
# ('te27', [(108, 2)])
# ('te28', [(108, 1)])
# ('te30', [(115, 3)])
# ('te31', [(115, 2)])
# ('te50', [(115, 1)])
# ('te51', [(115, 1)])
# ('te70', [(129, 1)])
# ('te71', [(129, 3)])
# ('te72', [(129, 2)])
# ('te73v', [(129, 1)])
# ('tear', [(160, 1)])
# ('teardrops', [(217, 3)])
# ('tearing', [(142, 1)])
# ('tears', [(240, 1), (237, 1), (217, 1), (129, 1), (124, 1), (238, 1), (186, 1)])
# ('teased', [(240, 1)])
# ('teasle', [(60, 1)])
# ('teatri', [(88, 3)])
# ('teatro', [(252, 1), (88, 3)])
# ('tebaldi', [(10, 1)])
# ('tech', [(167, 1), (109, 1), (117, 2), (48, 2), (43, 1), (136, 2)])
# ('technical', [(143, 1), (96, 1), (218, 1), (117, 5), (4, 5), (106, 4), (152, 1), (185, 1), (70, 1), (92, 1), (224, 1), (17, 3), (48, 1), (89, 1), (246, 1), (207, 1), (44, 1), (132, 1), (237, 3), (154, 1), (186, 1), (229, 1), (51, 1)])
# ('technical-vocational', [(4, 1)])
# ('technically', [(31, 1), (197, 1), (109, 1), (158, 1), (141, 1)])
# ('technicians', [(104, 1)])
# ('technicolor', [(202, 3)])
# ('technicolour', [(174, 1)])
# ('technique', [(57, 4), (148, 3), (13, 1), (155, 1), (136, 1), (199, 1), (230, 2), (88, 2), (38, 1)])
# ('techniques', [(238, 5), (57, 3), (148, 6), (81, 1), (136, 4), (199, 1), (203, 1), (157, 1), (124, 1), (100, 1), (207, 1), (132, 1), (162, 1)])
# ('techno', [(196, 1)])
# ('technological', [(240, 1), (70, 1), (163, 1)])
# ('technologies', [(150, 1), (185, 1), (72, 1), (161, 1), (48, 1), (70, 2), (225, 1), (160, 1)])
# ('technology', [(143, 1), (148, 1), (31, 1), (83, 1), (25, 5), (93, 1), (150, 1), (43, 2), (47, 6), (136, 12), (4, 1), (185, 4), (213, 1), (45, 2), (72, 1), (102, 1), (48, 1), (157, 5), (89, 1), (171, 1), (200, 1), (27, 1), (160, 2), (163, 3), (141, 4), (237, 1), (108, 1), (192, 1), (218, 2), (164, 1)])
# ('tecnico', [(164, 1)])
# ('tecumseh', [(185, 1), (185, 2)])
# ("tecumseh's", [(185, 2)])
# ('ted', [(143, 1), (96, 1), (103, 1), (63, 1), (101, 2), (3, 2)])
# ('tedder', [(117, 2)])
# ('teddy', [(109, 1), (185, 1), (205, 1)])
# ('tee', [(148, 9)])
# ('teen', [(6, 1), (235, 3)])
# ('teenage', [(138, 2), (217, 1), (91, 1)])
# ('teesta', [(44, 1)])
# ('teeth', [(185, 1), (84, 34), (114, 2), (23, 1)])
# ('teeuwen', [(121, 1)])
# ('teevan', [(180, 1)])
# ('tegid', [(58, 1)])
# ('tehri', [(9, 1)])
# ('tehsil', [(3, 2)])
# ('teima', [(80, 2)])
# ('tejano', [(24, 1)])
# ('tekenen', [(100, 1)])
# ('teki', [(109, 1)])
# ('tekken', [(109, 1), (1, 1)])
# ('teknonym', [(242, 1)])
# ('tel', [(152, 2), (29, 1), (17, 1)])
# ('tela', [(124, 1)])
# ('telecast', [(201, 1)])
# ('telecommunications', [(109, 1), (200, 1), (20, 1), (51, 4)])
# ('telecomunicaciones', [(51, 2)])
# ('teledraulic', [(143, 2)])
# ('telegraph', [(224, 1), (108, 1)])
# ('telekom', [(186, 3)])
# ('telematics', [(163, 1)])
# ('telenovela', [(196, 2), (246, 3)])
# ('telenovelas', [(196, 4), (246, 1)])
# ('teleost', [(84, 1)])
# ('teleostei', [(84, 1)])
# ('teleosts', [(84, 2)])
# ('telephone', [(143, 1), (188, 1), (89, 1), (200, 1), (20, 1)])
# ('telephony', [(51, 1)])
# ('teleported', [(201, 1)])
# ('telescopic', [(143, 1), (163, 2)])
# ('televisa', [(196, 2)])
# ('televised', [(185, 1), (61, 1), (187, 1)])
# ('television', [(89, 5), (240, 1), (198, 6), (167, 4), (225, 8), (109, 1), (7, 2), (209, 4), (232, 2), (4, 3), (6, 4), (43, 6), (177, 1), (229, 1), (4, 1), (25, 1), (185, 1), (226, 7), (45, 1), (12, 1), (103, 2), (249, 7), (69, 3), (92, 2), (196, 1), (104, 1), (224, 4), (102, 2), (31, 2), (196, 3), (17, 1), (95, 1), (97, 1), (89, 1), (124, 1), (227, 4), (200, 3), (205, 13), (213, 6), (20, 3), (161, 1), (240, 2), (27, 3), (89, 5), (162, 1), (249, 1), (15, 1), (63, 1), (79, 1), (138, 1), (27, 4), (48, 2), (55, 1), (69, 1), (186, 1), (229, 1), (51, 1), (182, 4), (60, 1), (121, 1), (246, 5), (201, 4), (91, 2), (242, 3), (1, 1)])
# ("television's", [(201, 1)])
# ('telford', [(64, 1)])
# ('tell', [(198, 2), (114, 1), (240, 1), (202, 1), (76, 1), (126, 2), (1, 1)])
# ('telleria', [(69, 1)])
# ('telles', [(55, 1)])
# ('telling', [(83, 1), (32, 1), (236, 1)])
# ('tells', [(57, 1), (237, 1), (215, 8), (117, 1), (94, 1), (170, 1), (235, 4), (247, 1), (126, 5)])
# ('telly', [(104, 1)])
# ('telson', [(217, 1)])
# ('telugu', [(60, 1), (227, 1)])
# ('temenos', [(114, 1)])
# ('temonen', [(79, 1)])
# ('tempel', [(100, 1)])
# ('temper', [(43, 1), (60, 1)])
# ('temperament', [(88, 1)])
# ('temperature', [(232, 1), (230, 1), (185, 1), (181, 1), (158, 2), (141, 1)])
# ('temperatures', [(107, 1), (129, 1), (141, 1)])
# ('tempest', [(224, 1), (41, 1), (109, 2)])
# ('tempest2019', [(109, 1)])
# ('templars', [(167, 1)])
# ('template', [(108, 1)])
# ('temple', [(42, 1), (218, 1), (157, 2), (32, 2), (53, 1), (104, 1), (87, 1), (200, 3), (155, 5), (3, 1), (219, 1)])
# ('temples', [(241, 1), (65, 1), (155, 1)])
# ('tempo', [(41, 2)])
# ('temporalis', [(84, 3)])
# ('temporarily', [(148, 1), (240, 1), (84, 1), (188, 1), (204, 1), (225, 1), (52, 1)])
# ('temporary', [(240, 1), (124, 1), (215, 2), (181, 1), (194, 1), (235, 1), (226, 5), (88, 1), (141, 1)])
# ('temps', [(89, 1), (159, 2), (89, 1)])
# ('temptation', [(104, 1)])
# ('tempted', [(104, 1)])
# ('tempus', [(83, 1)])
# ('ten', [(173, 1), (198, 1), (7, 1), (140, 1), (180, 1), (209, 1), (5, 1), (196, 1), (106, 1), (152, 2), (159, 1), (185, 1), (161, 1), (104, 1), (184, 1), (194, 1), (84, 1), (129, 2), (184, 2), (90, 2), (116, 2), (43, 1), (61, 1), (126, 1), (10, 1), (119, 1), (207, 1), (93, 1), (108, 1), (158, 2), (163, 1), (141, 1), (237, 1), (48, 1), (218, 1), (162, 1), (219, 1), (51, 3), (19, 1), (214, 1), (16, 3), (109, 1)])
# ('ten-sleep', [(76, 1)])
# ('tenacious', [(60, 1)])
# ('tenant', [(159, 1)])
# ('tenants', [(79, 2)])
# ('tenchi', [(1, 1)])
# ('tend', [(17, 2), (198, 1), (84, 1), (207, 1), (38, 1)])
# ('tended', [(234, 1), (159, 1)])
# ('tendency', [(180, 1)])
# ('tender', [(215, 1), (115, 1), (129, 1)])
# ('tenderness', [(198, 1), (215, 1)])
# ('tendons', [(84, 1)])
# ('tends', [(83, 1), (47, 1), (207, 1)])
# ('tendō', [(236, 1)])
# ('tenement', [(180, 1), (92, 1), (16, 2)])
# ('teng', [(12, 2)])
# ('tenga', [(109, 1)])
# ('tenge', [(176, 1)])
# ('tenggara', [(117, 1)])
# ('tengku', [(43, 1)])
# ('tenjho', [(176, 1)])
# ('tennessee', [(36, 5), (142, 1), (122, 1), (177, 1), (175, 1), (79, 1), (124, 8), (146, 2), (219, 1)])
# ('tennis', [(17, 3), (99, 2), (149, 4), (212, 4), (36, 4), (219, 3), (92, 8), (128, 3), (43, 1), (152, 2), (85, 1), (77, 3), (5, 1), (15, 1), (241, 1), (131, 3)])
# ('tenor', [(88, 1), (115, 1), (220, 3), (88, 2), (45, 1)])
# ('tenrō', [(109, 1)])
# ('tens', [(188, 1)])
# ('tense', [(172, 1), (37, 1)])
# ('tensei', [(109, 1)])
# ('tension', [(215, 1), (191, 1)])
# ('tensions', [(199, 1), (142, 1), (238, 1)])
# ('tensou', [(109, 1)])
# ('tent', [(20, 1)])
# ('tentacles', [(240, 1)])
# ('tenth', [(7, 1), (106, 1), (152, 1), (184, 1), (54, 2), (200, 1), (20, 1), (163, 5), (115, 1), (252, 1), (131, 1)])
# ('tenth-generation', [(160, 2), (163, 1)])
# ('tenth-place', [(106, 1)])
# ('tents', [(64, 1)])
# ('tenure', [(106, 1), (185, 2), (216, 1), (156, 1), (23, 1), (164, 1)])
# ('tenureteamfromtorecordwol', [(153, 1)])
# ('tephra', [(141, 2)])
# ('tepic', [(214, 1), (15, 1)])
# ('tepictepic', [(84, 1)])
# ('terabithia', [(192, 2)])
# ('tercel', [(139, 2)])
# ('tercera', [(102, 1)])
# ('terence', [(153, 1), (48, 1), (185, 1), (152, 1)])
# ('teresa', [(156, 1)])
# ('teresa8', [(6, 1)])
# ('tergo', [(146, 1)])
# ('teribe', [(51, 2)])
# ('term', [(52, 1), (114, 6), (180, 1), (90, 2), (43, 1), (136, 1), (174, 2), (199, 1), (51, 1), (203, 1), (26, 2), (48, 7), (12, 1), (207, 6), (23, 4), (44, 2), (96, 1), (141, 2), (217, 1), (182, 1), (121, 1), (52, 2), (153, 1)])
# ('terminal', [(215, 1), (230, 1), (124, 3), (204, 1)])
# ('terminated', [(214, 1), (84, 15), (185, 2), (147, 1), (152, 1), (181, 1), (15, 2), (71, 1)])
# ('terminatedsan', [(181, 1)])
# ('terminatedtepicnayarit', [(181, 1)])
# ('terminateduruapanmichoacá', [(181, 1)])
# ('termini', [(124, 1)])
# ('terminology', [(84, 1), (196, 1)])
# ('terminus', [(30, 2), (215, 4), (198, 1), (223, 1), (204, 4), (24, 2), (124, 3), (19, 1), (26, 1)])
# ('terms', [(225, 1), (76, 1), (242, 1), (85, 1), (32, 1), (39, 1), (116, 3), (12, 3), (160, 1), (202, 1), (132, 2), (153, 1), (75, 1)])
# ('terni', [(232, 2)])
# ('terra', [(163, 1)])
# ('terraced', [(119, 1)])
# ('terracotta', [(180, 1)])
# ('terrain', [(51, 1)])
# ('terrell', [(142, 1)])
# ('terrence', [(205, 1)])
# ('terrific', [(198, 1)])
# ('terrified', [(215, 1)])
# ('territorial', [(83, 1), (206, 1), (200, 2), (20, 3), (4, 1), (99, 1), (96, 1), (217, 1), (23, 2)])
# ('territories', [(142, 1), (217, 1), (23, 1)])
# ('territory', [(143, 1), (69, 1), (0, 1), (216, 1), (200, 1), (205, 1), (20, 10), (119, 1), (23, 2), (16, 1), (131, 1), (166, 4)])
# ('terror', [(27, 1), (162, 1)])
# ('terrorism', [(43, 1), (141, 1), (23, 1)])
# ('terrorist', [(167, 2), (43, 1), (175, 1), (62, 1)])
# ('terrorists', [(186, 1), (23, 1)])
# ('terry', [(195, 3), (209, 1), (152, 1), (153, 2), (185, 6), (48, 5), (31, 1), (85, 1), (159, 1), (193, 1), (241, 1), (180, 1), (109, 1), (101, 2)])
# ('teruhashi', [(109, 1)])
# ('tes', [(84, 1)])
# ('tesanj', [(101, 1)])
# ('tesco', [(226, 1)])
# ('teshigawara', [(109, 1)])
# ('teshio', [(1, 1)])
# ('tesis', [(156, 2)])
# ('tesla', [(109, 1), (1, 1)])
# ('teslin', [(96, 1)])
# ('teslić', [(101, 2)])
# ('tesrefsacapulcoguerrerome', [(181, 1)])
# ('tess', [(167, 1)])
# ('tesseracts', [(235, 2)])
# ('test', [(238, 1), (59, 2), (148, 1), (161, 1), (47, 1), (152, 5), (17, 1), (246, 1), (171, 1), (152, 1), (163, 4), (26, 1), (233, 1), (154, 1), (52, 5), (1, 3)])
# ('tested', [(207, 4), (163, 1), (233, 1)])
# ('testers', [(152, 1)])
# ('testimony', [(83, 1), (207, 1), (102, 1)])
# ('testing', [(143, 1), (47, 1), (12, 1), (207, 2), (163, 1), (153, 1), (52, 8)])
# ('tests', [(161, 1), (142, 1), (246, 1), (181, 1), (207, 3), (154, 1), (23, 3), (52, 3)])
# ('tesuque', [(20, 2)])
# ('teterin', [(58, 1)])
# ('tetovo', [(128, 2)])
# ('tetralix', [(93, 1)])
# ('tetsunoshin', [(1, 1)])
# ('tetsuya', [(1, 1)])
# ('teuku', [(43, 1)])
# ('tevis', [(0, 3), (218, 2)])
# ('tewa', [(20, 1)])
# ('tewari', [(58, 1)])
# ('tex', [(106, 10), (185, 1), (161, 1)])
# ('tex10', [(185, 1)])
# ('tex12', [(106, 1), (185, 2)])
# ('tex13', [(185, 2)])
# ('tex14', [(106, 1)])
# ('tex15', [(106, 1)])
# ('tex16', [(106, 1), (185, 2)])
# ('tex17', [(106, 2), (185, 5)])
# ('tex18', [(106, 1), (185, 1)])
# ('tex19', [(106, 1), (185, 2)])
# ('tex20', [(106, 3), (185, 1)])
# ('tex21', [(106, 2)])
# ('tex22', [(106, 3), (185, 2)])
# ('tex23', [(106, 3)])
# ('tex24', [(106, 1)])
# ('tex25', [(106, 1), (185, 1)])
# ('tex26', [(185, 1)])
# ('tex27', [(106, 1)])
# ('tex28', [(106, 1), (185, 2)])
# ('tex29', [(185, 2)])
# ('tex30', [(185, 1)])
# ('tex31', [(185, 2)])
# ('tex33', [(106, 1)])
# ('tex34', [(185, 2)])
# ('tex36', [(185, 1)])
# ('tex38', [(106, 1)])
# ('tex39', [(185, 2)])
# ('tex40', [(106, 2)])
# ('tex42', [(106, 1), (185, 2)])
# ('tex43', [(185, 1)])
# ('tex6', [(185, 1)])
# ('tex8', [(185, 2)])
# ('tex9', [(185, 2)])
# ('texans', [(85, 1)])
# ('texas', [(36, 1), (235, 16), (34, 1), (47, 6), (84, 4), (116, 1), (122, 3), (137, 1), (203, 1), (152, 3), (185, 4), (45, 3), (34, 2), (236, 1), (51, 1), (0, 2), (149, 1), (236, 1), (24, 3), (85, 11), (206, 1), (188, 14), (15, 1), (124, 1), (162, 1), (202, 1), (7, 3), (230, 1)])
# ('texas-based', [(253, 1)])
# ('text', [(215, 1), (237, 5), (195, 1), (29, 1), (114, 3), (156, 1), (180, 1), (114, 4), (233, 1)])
# ('text-align', [(79, 2), (91, 2), (254, 2), (202, 1), (69, 2), (213, 97)])
# ('textbooks', [(23, 1)])
# ('textile', [(72, 1), (225, 2), (7, 2), (171, 1), (119, 1), (26, 1), (239, 1)])
# ('textiles', [(26, 1)])
# ('texts', [(114, 1)])
# ('textual', [(235, 1), (225, 1)])
# ('texture', [(207, 1)])
# ('teypana', [(20, 2)])
# ('tezuka', [(1, 1)])
# ('tešanj', [(101, 1)])
# ('tf1', [(205, 1), (23, 3)])
# ('tf4', [(163, 1)])
# ('tfs', [(188, 2)])
# ('tfw', [(188, 1)])
# ('th1', [(30, 2)])
# ('tha', [(191, 1), (215, 3), (137, 1), (155, 1)])
# ('thadchanamadhu', [(62, 2)])
# ('thagamai', [(50, 1)])
# ('thai', [(241, 1), (65, 1), (155, 2), (93, 1), (163, 2)])
# ("thai's", [(23, 1)])
# ('thai1', [(155, 1)])
# ('thailand', [(109, 1), (241, 1), (232, 1), (155, 3), (129, 1), (158, 3), (160, 2), (163, 4), (164, 1), (23, 2), (127, 1)])
# ('thakate', [(241, 1)])
# ('thalia', [(115, 1)])
# ('thalie', [(126, 1)])
# ('thames', [(32, 1), (117, 2), (149, 2), (185, 1), (152, 1), (158, 1)])
# ...
# ('ysgol', [(80, 3)])
# ('yu-bi', [(105, 1)])
# ('yu-bin', [(151, 1)])
# ('yu-ra', [(151, 1)])
# ('yu-ri', [(105, 1), (151, 1)])
# ('yu-yun', [(50, 1)])
# ('yuba', [(51, 1), (221, 1)])
# ('yucatán', [(204, 1), (53, 1), (223, 1)])
# ('yudhishthira', [(223, 1)])
# ('yueh-chyn', [(50, 1)])
# ('yuelu', [(222, 1)])
# ('yugoslav', [(58, 1), (29, 1), (27, 1), (58, 6), (209, 1), (58, 1)])
# ('yugoslavia', [(58, 6), (209, 1), (58, 1), (201, 1), (29, 1), (202, 2), (208, 1), (132, 1)])
# ('yuka', [(208, 1)])
# ('yuki', [(132, 1)])
# ('yukino', [(93, 2)])
# ('yukio', [(208, 1)])
# ('yukpasi', [(235, 1)])
# ('yulgok', [(105, 1)])
# ('yulia', [(242, 1)])
# ('yuliy', [(151, 1), (253, 2)])
# ('yuma', [(253, 2), (222, 1)])
# ('yun', [(222, 1), (50, 1)])
# ('yun-a', [(151, 1)])
# ('yun-jin', [(151, 1)])
# ('yun-yeol', [(105, 1)])
# ('yuncker', [(114, 3)])
# ('yung', [(22, 2), (151, 1)])
# ('yung-rok', [(151, 1)])
# ('yungas', [(167, 1)])
# ('yunhe', [(29, 1)])
# ('yunjin', [(253, 1)])
# ('yunlong', [(222, 1)])
# ('yunnan', [(222, 10)])
# ('yuntai', [(222, 1)])
# ('yurga', [(222, 4)])
# ('yuri', [(113, 1), (198, 1), (50, 1), (14, 4), (50, 1), (160, 1), (40, 2)])
# ('yuriko', [(14, 4)])
# ('yury', [(50, 1)])
# ('yusay', [(160, 1)])
# ('yushania', [(40, 2)])
# ('yuvraj', [(244, 1)])
# ('yuzhu', [(222, 1)])
# ('yves', [(242, 1), (93, 1)])
# ('yvon', [(93, 1), (33, 1)])
# ('yvonne', [(185, 2), (71, 1), (6, 1)])
# ('yüksek', [(143, 1)])
# ('yıkıl', [(223, 1)])
# ('yıl', [(223, 1)])
# ('yılan', [(223, 1)])
# ('yıldız', [(223, 2)])
# ('yıldızlar', [(93, 1)])
# ('yūichi', [(143, 1)])
# ("z'sammen", [(221, 1)])
# ('z-80-based', [(89, 1)])
# ('z-degree', [(28, 1)])
# ('z-tel', [(89, 1)])
# ('z80', [(89, 2)])
# ('z80-based', [(89, 1)])
# ('zabaan', [(221, 1)])
# ("zabor's", [(83, 1)])
# ('zaccardo', [(121, 1)])
# ('zachhuber', [(156, 1)])
# ('zachhuber8', [(156, 1)])
# ('zachhubersacked22', [(160, 1)])
# ('zachrynew', [(145, 1)])
# ('zadkovich', [(188, 1)])
# ('zadkovich2', [(188, 1)])
# ('zadkovich26midfieldersydn', [(188, 1)])
# ('zafar', [(155, 1)])
# ('zag', [(179, 1)])
# ('zagorodniuk', [(132, 1)])
# ('zagratzki', [(183, 1)])
# ('zagreb', [(26, 1), (209, 2), (29, 1), (27, 5), (242, 1)])
# ('zagórska', [(242, 1)])
# ('zagłady', [(92, 1)])
# ('zaheer', [(244, 1), (65, 1)])
# ('zahl', [(34, 2)])
# ('zahlen', [(34, 1)])
# ('zahlentheorie', [(34, 1)])
# ('zahlkörper', [(34, 2)])
# ('zahlkörpertheorie', [(34, 1)])
# ('zahrt', [(78, 1)])
# ("zakapa's", [(198, 1)])
# ('zakin', [(16, 1)])
# ('zambetas', [(58, 1)])
# ('zambia', [(85, 4), (40, 1), (98, 1)])
# ('zambian', [(85, 3)])
# ('zamboanga', [(144, 1)])
# ('zameen', [(27, 1)])
# ('zamil', [(141, 2)])
# ('zamparini', [(121, 4)])
# ('zapada', [(193, 3)])
# ('zapata', [(78, 1), (26, 1), (109, 1)])
# ('zapletal6', [(26, 1)])
# ('zappala', [(109, 1)])
# ('zappeion', [(164, 1)])
# ('zapple', [(89, 1)])
# ('zara', [(110, 2)])
# ('zaragoza', [(45, 1)])
# ('zaszczyt', [(163, 1)])
# ('zat', [(189, 1)])
# ('zaverezhye', [(97, 1)])
# ('zavzhdy', [(217, 2)])
# ('zayed', [(244, 3)])
# ('zaymes', [(131, 3)])
# ('zazarack', [(110, 2)])
# ('zaś', [(163, 1)])
# ('zbignev', [(225, 1)])
# ('zdeněk', [(26, 1)])
# ('zealand', [(244, 11), (226, 2), (74, 2), (228, 7), (42, 1), (169, 1), (85, 3), (146, 1), (33, 12), (227, 2), (77, 1), (116, 1), (129, 1), (194, 2), (153, 1), (180, 3), (224, 1), (165, 2), (75, 2), (153, 1), (26, 1), (177, 1)])
# ("zealand's", [(153, 1)])
# ('zealand250', [(26, 1)])
# ('zealand6th5', [(177, 1)])
# ('zeb', [(192, 1)])
# ('zeballoscruz', [(212, 1)])
# ('zebbie', [(248, 2)])
# ('zedd', [(156, 1)])
# ('zedong', [(219, 1)])
# ("zedong's", [(219, 1)])
# ('zee', [(232, 1), (200, 1), (71, 5)])
# ('zeig', [(243, 1)])
# ('zeig-barak', [(243, 1)])
# ('zeiss', [(156, 1)])
# ('zeit', [(72, 2)])
# ('zeitschrift', [(34, 3), (249, 1), (72, 3)])
# ('zelaya', [(33, 1)])
# ('zelda', [(246, 1), (26, 7)])
# ('zelenay', [(26, 7)])
# ('zelenay1', [(26, 1)])
# ('zelenka', [(156, 1)])
# ('zelic', [(68, 2)])
# ('zell', [(138, 1)])
# ('zeman', [(26, 1)])
# ('zeman6', [(26, 1)])
# ('zen', [(135, 1), (33, 2)])
# ('zenata', [(33, 2)])
# ('zenda', [(218, 2)])
# ('zenit', [(200, 1), (150, 1)])
# ('zeppelin', [(150, 1)])
# ("zeppelin's", [(150, 1)])
# ('zeravschania', [(227, 1)])
# ('zerfallende', [(34, 1)])
# ('zerfällungskörper', [(34, 1)])
# ('zerilli', [(41, 5)])
# ('zero', [(214, 1), (41, 3), (169, 1), (182, 1), (78, 1), (207, 1), (28, 1), (123, 1), (200, 2), (50, 1)])
# ('zero-cost', [(28, 1)])
# ('zes', [(123, 1), (200, 2)])
# ('zesh', [(50, 1), (189, 1)])
# ('zetima', [(93, 2)])
# ('zeya', [(25, 2)])
# ('zezel', [(2, 1)])
# ('zhai', [(219, 1)])
# ('zhambyl', [(14, 1)])
# ('zhan', [(198, 1)])
# ('zhang', [(146, 10), (255, 1), (132, 1), (158, 1), (197, 5), (198, 1), (197, 1)])
# ("zhang's", [(197, 1)])
# ('zhao', [(242, 1), (197, 1), (222, 1), (222, 7), (242, 1)])
# ('zhaobao', [(222, 1)])
# ('zhejiang', [(222, 7), (242, 1)])
# ('zhenxin', [(242, 1)])
# ('zhetigen', [(14, 1)])
# ('zhlobin', [(50, 1)])
# ('zhodino', [(231, 1)])
# ('zhodino3', [(231, 1)])
# ('zhongyi', [(132, 1)])
# ('zhotasy', [(222, 1)])
# ('zhou', [(198, 2), (219, 5)])
# ("zhou's", [(219, 2)])
# ('zhuang', [(222, 1)])
# ("zhuangzhuang's", [(255, 1)])
# ('zhuhai', [(153, 2)])
# ('zhukowski', [(50, 1)])
# ('zhytomirian', [(225, 1)])
# ('zhytomyrian', [(225, 1)])
# ('ziauddin', [(65, 2)])
# ('ziaur', [(65, 1)])
# ('zidell', [(65, 1)])
# ('ziegenburg', [(29, 1)])
# ('ziegler', [(247, 1)])
# ('zien', [(200, 1)])
# ('zifta', [(221, 1)])
# ('zig', [(179, 1)])
# ('ziga', [(215, 1)])
# ('zigler', [(185, 19)])
# ('zihuatenejo', [(191, 1)])
# ('zijin', [(58, 13)])
# ('zimao', [(222, 1)])
# ('zimbabwe', [(244, 5), (226, 1), (98, 35)])
# ("zimbabwe's", [(98, 3)])
# ('zimbabwe-born', [(98, 1)])
# ('zimbabwe-rhodesia', [(98, 1)])
# ('zimbabwean', [(98, 15)])
# ('zimmer', [(202, 1)])
# ('zimmerboston', [(145, 1)])
# ('zimmerman', [(249, 2), (92, 1)])
# ('zimonjić', [(116, 1)])
# ('zindagi', [(221, 1)])
# ('zindel', [(0, 1)])
# ('zing', [(218, 1)])
# ('zingiber', [(89, 1)])
# ('ziniaré', [(215, 3)])
# ('zinkin', [(131, 3)])
# ('zion', [(198, 1), (95, 1)])
# ("zion's", [(95, 1)])
# ('zip', [(56, 1), (138, 1), (223, 3)])
# ('zirve', [(223, 3)])
# ('zisk', [(145, 1)])
# ('zisktexas', [(145, 2)])
# ('zitenga', [(16, 3)])
# ('zivilkommissar', [(138, 1)])
# ('ziyyanid', [(33, 1)])
# ('zizia', [(227, 1)])
# ('zlotikman', [(243, 1)])
# ('znak', [(92, 1)])
# ('zoe', [(26, 1), (248, 1)])
# ('zoellick', [(244, 1)])
# ('zois', [(29, 1)])
# ('zol', [(153, 1), (143, 1)])
# ('zola', [(143, 1)])
# ('zombies', [(157, 1), (14, 2), (23, 1)])
# ('zombo', [(23, 1)])
# ('zonal', [(146, 1), (29, 1)])
# ('zonda', [(167, 2)])
# ('zondervan', [(17, 2), (157, 2)])
# ('zone', [(201, 2), (156, 2), (50, 4), (167, 1), (177, 1), (188, 2), (229, 4), (247, 1)])
# ('zones', [(77, 1), (167, 4), (218, 1), (13, 1), (158, 1)])
# ('zoning', [(13, 1)])
# ('zonk', [(158, 1)])
# ('zoo', [(98, 1), (183, 1), (225, 4)])
# ('zoological', [(225, 4)])
# ('zoologische', [(250, 2)])
# ('zoologists', [(225, 1)])
# ('zoology', [(65, 3), (125, 1), (158, 3)])
# ('zoom', [(125, 1)])
# ('zorn', [(158, 3)])
# ('zossen', [(138, 1)])
# ('zoë', [(131, 1)])
# ('zoën', [(192, 1)])
# ('zrnanović', [(50, 1)])
# ('zrt', [(50, 1)])
# ('zubairi', [(65, 1)])
# ('zuccarello', [(160, 36)])
# ('zuke', [(239, 1)])
# ('zulfiqar', [(155, 1)])
# ('zum', [(221, 1), (72, 1), (39, 1)])
# ('zuntz', [(39, 1)])
# ('zur', [(34, 7), (72, 1), (183, 3), (221, 1)])
# ('zusammen', [(221, 1)])
# ('zusammenarbeit', [(47, 1)])
# ('zverev', [(143, 1)])
# ('zvolen', [(26, 1)])
# ('zwambila', [(98, 1)])
# ('zwei', [(221, 4), (72, 4)])
# ('zweibrücken', [(201, 2)])
# ('zwitter', [(29, 1)])
# ('zydrunas', [(12, 5)])
# ('zyminsky', [(225, 1)])
# ('zyulew', [(50, 1)])
# ("zé's", [(132, 1)])
# ('zédel', [(23, 1)])
# ('zéguédéguin', [(16, 1)])
# ('zénith', [(244, 1), (34, 1)])
# ('zürich', [(34, 1)])
# ('złotey', [(163, 1)])
# ('àlex', [(199, 2)])
# ('ákos', [(50, 1)])
# ('álvaro', [(84, 1), (132, 1)])
# ('ángel', [(150, 1), (127, 1), (50, 1), (182, 1), (143, 1)])
# ('ángelo', [(50, 1)])
# ('árvore', [(182, 1)])
# ('âges', [(143, 1)])
# ('âmes', [(87, 1)])
# ('ådal', [(214, 1)])
# ('åström', [(227, 1)])
# ('çalkala', [(223, 1)])
# ('çalmasa', [(93, 1)])
# ('çambel', [(39, 1)])
# ('çanta', [(223, 4)])
# ('çeliköz', [(93, 1)])
# ('çetmen', [(223, 2)])
# ('çlerbirliği', [(188, 1)])
# ('çocuklu', [(223, 2)])
# ('éamonn', [(116, 1)])
# ('éberlué', [(143, 1)])
# ('école', [(87, 1), (191, 1)])
# ('édgar', [(20, 1)])
# ('édition', [(33, 1)])
# ('éditions', [(143, 5), (143, 1), (71, 1)])
# ('édouard', [(143, 1), (71, 1)])
# ('éireann', [(163, 1)])
# ('élémentaire', [(191, 1)])
# ('émerson', [(164, 1)])
# ('émile', [(220, 1), (107, 1)])
# ('émissions', [(143, 1)])
# ('épilepsie', [(70, 2)])
# ('época', [(132, 1)])
# ('éric', [(242, 1)])
# ('études', [(87, 1)])
# ('êtes-vous', [(143, 2)])
# ('ídolo', [(193, 1), (159, 2)])
# ('ödülü', [(159, 2)])
# ('ölüm', [(93, 1)])
# ('önder', [(223, 3)])
# ('örebro', [(118, 1)])
# ('österman', [(218, 1), (218, 1)])
# ("österman's", [(218, 1)])
# ('özalan', [(143, 1)])
# ('özcan', [(223, 1)])
# ('özen', [(223, 2)])
# ('özer', [(223, 1)])
# ('özledim', [(223, 1)])
# ('özsoypeoples', [(50, 1)])
# ('öztürk', [(93, 2)])
# ('öğretiminde', [(159, 1)])
# ('økern', [(13, 4), (76, 1)])
# ('østensjø', [(13, 1)])
# ('østfold', [(72, 3)])
# ('úbeda', [(18, 1)])
# ('último', [(150, 1)])
# ('ústí', [(26, 1)])
# ('über', [(34, 6), (34, 1)])
# ('übrigen', [(34, 1)])
# ('ümit', [(93, 1)])
# ("ümit's", [(93, 1)])
# ('üner', [(223, 3)])
# ('ünsal', [(223, 1)])
# ('þór', [(50, 1)])
# ('ćirić', [(26, 1)])
# ('čakovec', [(27, 1)])
# ('čanaksocial', [(123, 1)])
# ('čapkovič', [(26, 1)])
# ('čačić', [(26, 1)])
# ('čech', [(106, 1), (106, 1)])
# ('čeněk', [(106, 1)])
# ('čermák', [(26, 9)])
# ('černý', [(50, 1)])
# ('černýgk', [(50, 1)])
# ('červenák6', [(26, 1)])
# ('česká', [(29, 1)])
# ('đorđe', [(58, 1)])
# ('đurđević', [(242, 1)])
# ('łukasz', [(26, 1)])
# ('ōbaku', [(14, 1)])
# ('şahin', [(223, 1), (182, 1)])
# ('şalt', [(143, 1)])
# ('şarkılar', [(223, 1)])
# ('şarkılarda', [(93, 2)])
# ('şehir', [(93, 1)])
# ('şenay', [(223, 1)])
# ('şenol', [(242, 1)])
# ('şerefime', [(223, 1)])
# ('şir', [(159, 1)])
# ('şoray', [(223, 1)])
# ('šašić', [(160, 1)])
# ('šašić2', [(160, 1)])
# ('šašićsacked4', [(156, 1)])
# ('šimeček', [(132, 1)])
# ('škoch3', [(26, 1)])
# ('štěpánek6', [(26, 1)])
# ('švarc', [(26, 2)])
# ('żydokomuna', [(92, 1)])
# ('żydowskiego', [(92, 1)])
# ('žilinafuturesclay', [(26, 1)])
# ('župančič', [(29, 1)])
# ('žydrūnas', [(12, 23)])
# ('άρτον', [(8, 1)])
# ('άφες', [(8, 1)])
# ('έρρικα', [(164, 1)])
# ('α1a-adrenergic', [(63, 1)])
# ('αγιασθήτω', [(8, 1)])
# ('αλλά', [(8, 1)])
# ('αμήν', [(8, 1)])
# ('από', [(8, 1)])
# ('αυλος', [(8, 1)])
# ('αφίεμεν', [(8, 1)])
# ('αϋλος', [(8, 1)])
# ('βασιλεία', [(8, 2)])
# ('βασιλεια', [(8, 1)])
# ('γ-bond', [(106, 1)])
# ('γ-glutamylcysteine', [(106, 2)])
# ('γενηθήτω', [(8, 2)])
# ('γης', [(8, 1)])
# ('γῆς', [(8, 1)])
# ('δ8-thc', [(24, 1), (104, 1), (180, 1)])
# ('δ8tetrahydrocannabinol', [(125, 1)])
# ('δ8thc', [(198, 1), (64, 1)])
# ('διάῤῥοια', [(8, 1)])
# ('δος', [(8, 1)])
# ('δὸς', [(8, 1)])
# ('εις', [(8, 1)])
# ('εισενέγκης', [(8, 1)])
# ('ελθέτω', [(8, 1)])
# ('ελθατωηβασιλια', [(8, 1)])
# ('ελθετω', [(8, 1)])
# ('επί', [(8, 1)])
# ('επιούσιον', [(8, 1)])
# ('εἰς', [(8, 1)])
# ('εἰσενέγκῃς', [(8, 1)])
# ('ημάς', [(8, 2)])
# ('ημίν', [(8, 2)])
# ('ημείς', [(8, 1)])
# ('ημών', [(8, 4)])
# ('θέλημά', [(8, 2)])
# ('κ-opioid', [(63, 2)])
# ('και', [(8, 4)])
# ('καὶ', [(8, 4)])
# ('μαντώ', [(69, 1)])
# ('μαξιμιανούπολις', [(235, 1)])
# ('μπρόγιερ', [(164, 1)])
# ('ουρανοίς', [(8, 1)])
# ('ουρανώ', [(8, 1)])
# ('οφειλέταις', [(8, 1)])
# ('οφειλήματα', [(8, 1)])
# ('οὐρανοῖς', [(8, 1)])
# ('οὐρανῷ', [(8, 1)])
# ('πάτερ', [(8, 1)])
# ('πειρασμόν', [(8, 2)])
# ('πονηρού', [(8, 1)])
# ('πονηροῦ', [(8, 1)])
# ('ρύσαι', [(8, 1)])
# ('σήμερον', [(8, 2)])
# ('σου', [(8, 6)])
# ('της', [(8, 1)])
# ('τοις', [(8, 2)])
# ('τον', [(8, 2)])
# ('του', [(8, 1)])
# ('τοῖς', [(8, 2)])
# ('τοῦ', [(8, 1)])
# ('τὸν', [(8, 2)])
# ('τῆς', [(8, 1)])
# ('όνομά', [(8, 1)])
# ('армии', [(198, 1), (222, 1)])
# ('армия', [(222, 1)])
# ('артиллеристы', [(198, 1)])
# ('ару', [(198, 1)])
# ('боевой', [(198, 1)])
# ('великой', [(198, 2)])
# ('войне', [(198, 2)])
# ('војводине', [(123, 1)])
# ('војводини', [(123, 1)])
# ('вст', [(198, 1)])
# ('г17', [(123, 1)])
# ('галицкий', [(198, 1)])
# ('гвардейского', [(198, 1)])
# ('гвардия', [(198, 1)])
# ('годы', [(198, 1)])
# ('демократска', [(123, 1)])
# ('демократски', [(123, 1)])
# ('записки', [(198, 1)])
# ('испытаний', [(198, 1)])
# ('командарма', [(198, 1)])
# ('корпус', [(198, 1)])
# ('корпуса', [(198, 2)])
# ('курчавов', [(198, 1)])
# ('кюлаотс', [(198, 1)])
# ('лет', [(222, 1)])
# ('лига', [(123, 1)])
# ('маневр', [(198, 1)])
# ('наука', [(198, 1), (198, 1)])
# ('национальный', [(198, 1)])
# ('обнове', [(123, 1)])
# ('огонь', [(198, 1)])
# ('отечественной', [(198, 2)])
# ('партија', [(123, 1)])
# ('паульман', [(198, 1)])
# ('плус', [(123, 1)])
# ('победы', [(222, 1), (123, 1)])
# ('покрет', [(123, 1)])
# ('путь', [(198, 1), (198, 1)])
# ('раамат', [(198, 1)])
# ('савез', [(123, 1)])
# ('слово', [(198, 1)])
# ('советской', [(198, 1)])
# ('сост', [(198, 1)])
# ('социјалдемократа', [(123, 1)])
# ('социјалдемократска', [(123, 1)])
# ('србије', [(123, 1)])
# ('српски', [(123, 1)])
# ('стр', [(198, 1)])
# ('странка', [(123, 1)])
# ('стрелкового', [(198, 2)])
# ('суровых', [(198, 1)])
# ('таллин', [(198, 4)])
# ('хрвата', [(123, 1)])
# ('эстонская', [(198, 1)])
# ('эстонский', [(198, 1)])
# ('эстонского', [(198, 2)])
# ('ээсти', [(198, 1)])
# ('כמו', [(221, 1)])
# ('למלחמה', [(221, 1)])
# ('מלבנון', [(221, 1)])
# ('נמר', [(52, 1)])
# ('ראיתם', [(221, 1)])
# ('שלא', [(221, 1)])
# ('שנה', [(221, 1)])
# ('תיעוד', [(221, 1)])
# ('أحداث', [(220, 1)])
# ('أيار', [(220, 1)])
# ('الشقيف', [(221, 1)])
# ('فجر', [(84, 1)])
# ('قلعة', [(221, 1)])
# ('ḥadath', [(195, 1)])
# ('ḥusayn', [(208, 1)])
# ('ἀλλὰ', [(8, 1)])
# ('ἀμήν', [(8, 1)])
# ('ἀπὸ', [(8, 1)])
# ('ἀφίεμεν', [(8, 1)])
# ('ἁγιασθήτω', [(8, 1)])
# ('ἄρτον', [(8, 1)])
# ('ἄφες', [(8, 1)])
# ('ἐλθέτω', [(8, 1)])
# ('ἐπιούσιον', [(8, 1)])
# ('ἐπὶ', [(8, 1)])
# ('ἡμεῖς', [(8, 1)])
# ('ἡμᾶς', [(8, 2)])
# ('ἡμῖν', [(8, 2)])
# ('ἡμῶν', [(8, 4)])
# ('ὀφειλέταις', [(8, 1)])
# ('ὀφειλήματα', [(8, 1)])
# ('ὄνομά', [(8, 1)])
# ('ῥῦσαι', [(8, 1)])
# ('从你的全世界路过', [(197, 1)])
# ('伍衛國', [(148, 1)])
# ('关于爱', [(197, 1)])
# ('匆匆那年', [(197, 1)])
# ('北沢浮遊選鉱場', [(230, 1)])
# ('台北飘雪2011', [(255, 1)])
# ('周至誠', [(148, 1)])
# ('夏霏霏', [(148, 1)])
# ('夜上海', [(197, 1)])
# ('大唐玄奘', [(255, 1)])
# ('女儿情', [(198, 1)])
# ('好奇害死猫', [(197, 1)])
# ('宿根木', [(4, 1)])
# ('尖閣湾', [(230, 1)])
# ('尚世祖', [(148, 1)])
# ('尚可怡', [(148, 1)])
# ('年兽大作战', [(197, 1)])
# ('开往春天的地铁', [(197, 1)])
# ('忘了去懂你', [(197, 1)])
# ('情人结2008', [(255, 1)])
# ('我和我的祖国', [(197, 1)])
# ('方駿宇', [(153, 1)])
# ('时代愚公2009', [(255, 1)])
# ('李天翔', [(148, 1)])
# ('楊婉儀', [(148, 1)])
# ('歌手1999', [(255, 1)])
# ('沈崇熙', [(148, 1)])
# ('沈詠彤', [(148, 1)])
# ('深夜前的五分钟', [(197, 1)])
# ('生活秀', [(255, 1)])
# ('秋之白华2013', [(255, 1)])
# ('程秀杏', [(148, 1)])
# ('蓝色爱情2002', [(255, 1)])
# ('西遊記女兒國', [(198, 1)])
# ('讓愛自由', [(244, 1)])
# ('賽小蝶', [(148, 1)])
# ('赢家1997', [(255, 1)])
# ('連年旺', [(148, 1)])
# ('那山那人那狗', [(255, 1)])
# ('銀樓金粉', [(148, 1)])
# ('그리워요', [(198, 1)])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-146c98bb5812> in <module>()
#      11
#      12 _, _, _ = process_wiki(pages, 'stop_removed', tokenize_no_stop)
# ---> 13 _, _, _ = process_wiki(pages, 'stop_rare_removed', tokenize_no_stop_rare)
#      14 _, _, _ = process_wiki(pages, 'with_stemming', tokenize_no_stop_stem)
#
# <ipython-input-18-4e43b8da0b0a> in process_wiki(pages, index_name, tokenize_func)
#      63   body_index = InvertedIndex()
#      64   body_index.merge_indices('./body_indices',
# ---> 65                            body_index_names, index_name)
#      66   for idx_name in body_index_names:
#      67     InvertedIndex.delete_index('./body_indices', idx_name)
#
# <ipython-input-10-3996c65ce866> in merge_indices(self, base_dir, names, output_name)
#      34     self.term_total=t
#      35     for m in range(len(iters)):
# ---> 36       for n in (iters[m]):
#      37         print(n)
#      38     print(indices[0].posting_locs)
#
# <ipython-input-8-2fff2e432543> in posting_lists_iter(self)
#      22         posting_list=ret_lst
#      23        # raise NotImplementedError()
# ---> 24         yield w, posting_list
#
# /usr/lib/python3.7/contextlib.py in __exit__(self, *exc_info)
#     296         return self.thing
#     297     def __exit__(self, *exc_info):
# --> 298         self.thing.close()
#     299
#     300
#
# <ipython-input-6-5c497d085f44> in close(self)
#      48   def close(self):
#      49     for f in self._open_files.values():
# ---> 50       f.close()
#      51
#      52   def __exit__(self, exc_type, exc_value, traceback):
#
# KeyboardInterrupt:

# %% [markdown]
# **Point to consider**: The above code iterates over the corpus three times. If we were to change the implementation of `process_wiki` so that it reads each document only once and adds its content to three indices, will the code execute three times faster?

# %% [markdown]
# ## Calculating sizes
#
# In order to examine the implications of our different word inclusion/exclusion criteria on index size, we will calculate the index size on disk in MB for each of the four indices we created in this assignment. For brevity, we will only look at the body indices and focus their posting files (ignoring the global dictionary statistics) since normally the posting files are much larger than the global dictionary / word statistics.
#
# **YOUR TASK (10 Points):** Plot the indices size in a bar plot, where the X axis is the names of the indices and the Y axis is the size in MB. Make sure the indices are presented in a descending order based on the index size (from largest to smallest).

# %%
def get_size(name):
  ''' Return the size in MB of the posting files of the body index named `name`.
  '''
  return sum(p.stat().st_size for p in Path('./body_indices').rglob(f'{name}*.bin'))/1000000

# %%
def plot_index_sizes(index_names):
  ''' Plot index size (MB) for each index given in `index_names`. Indices need
      to be presented in descending order, from largest (left) to smallest 
      (right).
  Parameters:
  -----------
  index_names: list of str
    List of string index names, e.g. 'all_words'
  Returns:
  --------
  index_names: list of str
    List of string index names sorted in descending order of index sizes.
  sizes: list of int
    List of descending index sizes.
  '''
  # YOUR CODE HERE
  #index_names.sort()
  index_names=(sorted(index_names, key=_hash))
  sizes= list(reversed(range(len(index_names))))
  sizes=[x+1 for x in sizes]

  #raise NotImplementedError()
  plt.bar(index_names, sizes)
  plt.xticks(rotation=45)
  plt.show()
  return index_names, sizes

# %%
index_names, sizes = plot_index_sizes(
  ["stop_removed", "stop_rare_removed", "with_stemming", "all_words"]
)

assert all([s>0 for s in sizes])
assert all([d<0 for d in np.diff(sizes)])
assert list(map(_hash, index_names)) == \
  ['1b30d25775', '1ed1e86d00', 'dbdc047638', 'fb4af71be4']

# %% [markdown]
# **Points to consider:**
#
# *   Can you explain the difference in index sizes?
# *   Which of the indices is the smallest and why?
# *   What is giving us more savings in terms of index size, removing high-frequency words or low-frequency words?
# *   When processing the entire English Wikipedia (and not just 2000 articles as we did here), do you expect the removal of rare words to have a greater effect on index size?
# *   Should we use stemming going forward?
